# %% [markdown]
# # 🏦 Roth Conversion Optimizer for Rajesh & Terri
#
# ## 📑 NOTEBOOK GUIDE
#
# > **⭐ TIP: Use VS Code's OUTLINE panel (left sidebar) to jump between sections!**
# >
# > Or use **Ctrl+G** and type a line number to jump directly.
#
# ### 📍 KEY SECTIONS:
#
# | What You Want | Where to Find It |
# |---------------|------------------|
# | **📖 YOUR RETIREMENT STORY** | Scroll to **line ~2213** or look for `⭐⭐⭐` in Outline |
# | Your account data | Top of notebook (lines 28-127) |
# | Conversion optimization results | Line ~1619 |
# | RMD analysis | Line ~1717 |
# | Zero RMD analysis | Line ~1764 |
# | $50K RMD target | Line ~1986 |
#
# ---
#
# ### 🚀 QUICK START:
# 1. **Run All Cells**: Click ▶▶ "Run All" in the toolbar (or Shift+Enter through cells)
# 2. **Find Your Story**: Press **Ctrl+G**, type **2213**, press Enter
# 3. Your personalized summary with all recommendations is there!
#
# ---
#
# ### 🔍 USING THE OUTLINE:
# 1. Click the **Outline** icon in VS Code's left sidebar (looks like a list)
# 2. You'll see all section headers - click any to jump there
# 3. Look for **"⭐⭐⭐ 📖 YOUR RETIREMENT STORY ⭐⭐⭐"**
#
# ---

# %%
# =============================================================================
# 📝 ENTER YOUR HOUSEHOLD DATA HERE
# =============================================================================

# --- SPOUSE 1 (You) ---
SPOUSE1_NAME = "Rajesh"
SPOUSE1_AGE = 60
SPOUSE1_RETIREMENT_AGE = 65           # Age you plan to retire / stop working
SPOUSE1_TRADITIONAL_IRA = 831_211      # Traditional IRA balance
SPOUSE1_SEP_IRA = 88_152               # SEP-IRA balance
SPOUSE1_ROTH_IRA = 0                  # Roth IRA balance
SPOUSE1_SS_START_AGE = 67             # Age you'll start Social Security (62-70)
SPOUSE1_SS_ANNUAL_BENEFIT = 58_860    # Expected ANNUAL SS benefit at start age (from ssa.gov)

# --- SPOUSE 2 (Wife) ---
SPOUSE2_NAME = "Terri"
SPOUSE2_AGE = 61
SPOUSE2_RETIREMENT_AGE = 65           # Age spouse plans to retire
SPOUSE2_TRADITIONAL_IRA = 1_587_530     # Traditional IRA balance
SPOUSE2_SEP_IRA = 274_116              # SEP-IRA balance
SPOUSE2_ROTH_IRA = 0                  # Roth IRA balance
SPOUSE2_SS_START_AGE = 65             # Age spouse will start Social Security
SPOUSE2_SS_ANNUAL_BENEFIT = 27_996    # Expected ANNUAL SS benefit at start age (from ssa.gov)

# --- JOINT ACCOUNTS ---
JOINT_TAXABLE_ACCOUNTS = 439_514       # After-tax brokerage, savings, etc.

# --- CURRENT INCOME SOURCES (annual amounts while working) ---
CURRENT_WORK_INCOME = 0               # Current annual wages/self-employment (0 if retired)
PENSION_INCOME = 0                    # Annual pension income (if any)
OTHER_INCOME = 0                      # Other income (rental, dividends, etc.)

# =============================================================================
# 💰 GUARANTEED INCOME REQUIREMENT
# =============================================================================
MONTHLY_INCOME_NEED = 11_000          # Monthly income needed for quality of life
ANNUAL_INCOME_NEED = MONTHLY_INCOME_NEED * 12  # = $132,000/year

# =============================================================================
# 💵 MINIMUM CASH RESERVE (Emergency Fund)
# =============================================================================
MINIMUM_CASH_RESERVE = 75_000         # Always keep at least this much in taxable account
                                       # This is your "cash on hand" regardless of conversions

# =============================================================================
# TAX & PLANNING PARAMETERS
# =============================================================================
STATE_TAX_RATE = 0.04                 # State tax rate (0 for no state tax)
INFLATION_RATE = 0.025                # Expected inflation (2.5% = 0.025)
TARGET_BRACKET = 0.22                 # Target bracket to fill (10%, 12%, 22%, 24%, 32%, 35%)

# --- ASSET ALLOCATION BY ACCOUNT TYPE ---
# Format: (stocks_pct, bonds_pct) - should sum to 1.0
# More aggressive = higher stock allocation = higher expected return

TAXABLE_ALLOCATION = (0.70, 0.30)     # Post-tax/brokerage: 70% stocks, 30% bonds
IRA_ALLOCATION = (0.60, 0.40)         # Traditional IRA/SEP: 60% stocks, 40% bonds  
ROTH_ALLOCATION = (0.80, 0.20)        # Roth IRA: 80% stocks, 20% bonds

# Expected returns by asset class (long-term nominal)
STOCK_RETURN = 0.08                   # Expected stock return (8%)
BOND_RETURN = 0.04                    # Expected bond return (4%)

# =============================================================================
# CALCULATED VALUES
# =============================================================================

# Calculate expected returns for each account type based on allocation
TAXABLE_RETURN = TAXABLE_ALLOCATION[0] * STOCK_RETURN + TAXABLE_ALLOCATION[1] * BOND_RETURN
IRA_RETURN = IRA_ALLOCATION[0] * STOCK_RETURN + IRA_ALLOCATION[1] * BOND_RETURN
ROTH_RETURN = ROTH_ALLOCATION[0] * STOCK_RETURN + ROTH_ALLOCATION[1] * BOND_RETURN

# For backward compatibility
EXPECTED_RETURN = IRA_RETURN

# Social Security
SPOUSE1_SS_ANNUAL = SPOUSE1_SS_ANNUAL_BENEFIT
SPOUSE2_SS_ANNUAL = SPOUSE2_SS_ANNUAL_BENEFIT
SPOUSE1_SS_MONTHLY = SPOUSE1_SS_ANNUAL / 12
SPOUSE2_SS_MONTHLY = SPOUSE2_SS_ANNUAL / 12

print("✓ Data entered!")
print(f"\n{SPOUSE1_NAME}: Retire at {SPOUSE1_RETIREMENT_AGE}, SS starts at {SPOUSE1_SS_START_AGE}")
print(f"  Annual SS: ${SPOUSE1_SS_ANNUAL:,.0f}  (${SPOUSE1_SS_MONTHLY:,.0f}/month)")
print(f"{SPOUSE2_NAME}: Retire at {SPOUSE2_RETIREMENT_AGE}, SS starts at {SPOUSE2_SS_START_AGE}")
print(f"  Annual SS: ${SPOUSE2_SS_ANNUAL:,.0f}  (${SPOUSE2_SS_MONTHLY:,.0f}/month)")

print(f"\n💰 GUARANTEED INCOME REQUIREMENT:")
print(f"  Monthly Need: ${MONTHLY_INCOME_NEED:,.0f}/month")
print(f"  Annual Need:  ${ANNUAL_INCOME_NEED:,.0f}/year")

print(f"\n💵 MINIMUM CASH RESERVE:")
print(f"  Always keep: ${MINIMUM_CASH_RESERVE:,.0f} in taxable account")

print(f"\n📊 Asset Allocation & Expected Returns:")
print(f"  Taxable Account:  {TAXABLE_ALLOCATION[0]*100:.0f}/{TAXABLE_ALLOCATION[1]*100:.0f} → {TAXABLE_RETURN*100:.1f}% return")
print(f"  Traditional IRA:  {IRA_ALLOCATION[0]*100:.0f}/{IRA_ALLOCATION[1]*100:.0f} → {IRA_RETURN*100:.1f}% return")
print(f"  Roth IRA:         {ROTH_ALLOCATION[0]*100:.0f}/{ROTH_ALLOCATION[1]*100:.0f} → {ROTH_RETURN*100:.1f}% return")

print(f"\nNow click 'Run All' or run remaining cells.")

# %%
# Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize, differential_evolution
from dataclasses import dataclass
from typing import List, Tuple, Dict, Optional
import warnings
warnings.filterwarnings('ignore')

print("Libraries loaded successfully!")

# %% [markdown]
# ## 📊 Section 1: Tax Brackets & Calculation Functions
# **What this does:** Sets up the 2024 federal tax brackets and functions to calculate taxes on conversions.

# %%
# 2024 Federal Tax Brackets (Married Filing Jointly)
# Each tuple: (upper_limit, rate)
TAX_BRACKETS_MFJ_2024 = [
    (23200, 0.10),
    (94300, 0.12),
    (201050, 0.22),
    (383900, 0.24),
    (487450, 0.32),
    (731200, 0.35),
    (float('inf'), 0.37)
]

# 2024 Federal Tax Brackets (Single)
TAX_BRACKETS_SINGLE_2024 = [
    (11600, 0.10),
    (47150, 0.12),
    (100525, 0.22),
    (191950, 0.24),
    (243725, 0.32),
    (609350, 0.35),
    (float('inf'), 0.37)
]

# Standard Deductions for 2024
STANDARD_DEDUCTION_MFJ_2024 = 29200
STANDARD_DEDUCTION_SINGLE_2024 = 14600
STANDARD_DEDUCTION_65_PLUS_ADDITION = 1550  # Additional for 65+ (per person)

print("Tax brackets loaded for 2024")

# %%
@dataclass
class SpouseAccounts:
    """Individual spouse's retirement accounts and income timing."""
    name: str
    age: int
    traditional_ira: float = 0.0      # Traditional IRA balance
    sep_ira: float = 0.0              # SEP-IRA balance
    roth_ira: float = 0.0             # Roth IRA balance
    retirement_age: int = 65          # Age planning to retire
    ss_start_age: int = 67            # Age to start Social Security
    ss_annual_benefit: float = 0.0    # Annual SS benefit at start age
    
    @property
    def total_pretax(self) -> float:
        """Total pre-tax retirement accounts (subject to conversion/RMDs)."""
        return self.traditional_ira + self.sep_ira
    
    @property
    def total_roth(self) -> float:
        """Total Roth accounts."""
        return self.roth_ira
    
    def is_retired(self, year: int) -> bool:
        """Check if spouse is retired in given year."""
        return self.age + year >= self.retirement_age
    
    def is_collecting_ss(self, year: int) -> bool:
        """Check if spouse is collecting Social Security in given year."""
        return self.age + year >= self.ss_start_age
    
    def get_ss_income(self, year: int, inflation_rate: float = 0.025) -> float:
        """Get Social Security income for given year (with COLA adjustment)."""
        if not self.is_collecting_ss(year):
            return 0.0
        # Apply COLA from SS start age
        years_collecting = (self.age + year) - self.ss_start_age
        return self.ss_annual_benefit * ((1 + inflation_rate) ** years_collecting)


@dataclass 
class HouseholdProfile:
    """Complete household profile for married couple Roth conversion planning."""
    # Spouse information
    spouse1: SpouseAccounts
    spouse2: SpouseAccounts
    
    # Joint/Household information
    joint_taxable_accounts: float = 0.0    # After-tax brokerage accounts
    
    # Income sources (annual amounts)
    work_income: float = 0.0               # Current work income (wages, self-employment)
    pension_income: float = 0.0            # Combined pension income
    other_income: float = 0.0              # Other taxable income (rental, dividends, etc.)
    
    # Tax and planning parameters
    state_tax_rate: float = 0.0            # State income tax rate
    expected_return: float = 0.06          # Expected investment return
    inflation_rate: float = 0.025          # Expected inflation
    target_bracket: float = 0.22           # Target tax bracket to fill
    
    @property
    def total_pretax(self) -> float:
        """Total household pre-tax retirement accounts."""
        return self.spouse1.total_pretax + self.spouse2.total_pretax
    
    @property
    def total_roth(self) -> float:
        """Total household Roth accounts."""
        return self.spouse1.total_roth + self.spouse2.total_roth
    
    def get_income_for_year(self, year: int) -> Dict[str, float]:
        """Get all income sources for a specific year."""
        inflation_factor = (1 + self.inflation_rate) ** year
        
        # Work income stops at retirement (use earlier retirement age)
        both_retired = self.spouse1.is_retired(year) and self.spouse2.is_retired(year)
        work = 0 if both_retired else self.work_income * inflation_factor
        
        # Social Security (each spouse may start at different times)
        ss1 = self.spouse1.get_ss_income(year, self.inflation_rate)
        ss2 = self.spouse2.get_ss_income(year, self.inflation_rate)
        
        # Other income (inflation adjusted)
        pension = self.pension_income * inflation_factor
        other = self.other_income * inflation_factor
        
        return {
            'work_income': work,
            'spouse1_ss': ss1,
            'spouse2_ss': ss2,
            'total_ss': ss1 + ss2,
            'pension': pension,
            'other': other
        }
    
    def get_taxable_income_for_year(self, year: int) -> float:
        """Get total taxable income for a year (excluding conversions)."""
        income = self.get_income_for_year(year)
        
        # Social Security is partially taxable (85% for higher incomes)
        ss_taxable = 0.85 * income['total_ss']
        
        return income['work_income'] + ss_taxable + income['pension'] + income['other']
    
    @property
    def total_taxable_income(self) -> float:
        """Total current taxable income (for backward compatibility)."""
        return self.get_taxable_income_for_year(0)
    
    def get_standard_deduction(self, year: int = 0) -> float:
        """Calculate standard deduction for MFJ based on ages."""
        inflation_factor = (1 + self.inflation_rate) ** year
        
        base = STANDARD_DEDUCTION_MFJ_2024
        extra = 0
        
        # Add extra deduction for each spouse 65+
        if self.spouse1.age + year >= 65:
            extra += STANDARD_DEDUCTION_65_PLUS_ADDITION
        if self.spouse2.age + year >= 65:
            extra += STANDARD_DEDUCTION_65_PLUS_ADDITION
        
        return (base + extra) * inflation_factor
    
    def get_tax_brackets(self, year: int = 0) -> List[Tuple[float, float]]:
        """Get inflation-adjusted tax brackets for MFJ."""
        inflation_factor = (1 + self.inflation_rate) ** year
        
        adjusted_brackets = []
        for limit, rate in TAX_BRACKETS_MFJ_2024:
            if limit == float('inf'):
                adjusted_brackets.append((limit, rate))
            else:
                adjusted_brackets.append((limit * inflation_factor, rate))
        
        return adjusted_brackets


# Legacy single-person profile for backward compatibility
@dataclass
class TaxpayerProfile:
    """Profile containing taxpayer information for Roth conversion planning."""
    name: str
    age: int
    filing_status: str  # 'single' or 'mfj' (married filing jointly)
    traditional_ira_balance: float
    roth_ira_balance: float
    other_taxable_income: float  # Social Security, pensions, wages, etc.
    state_tax_rate: float  # State income tax rate (0 for no state tax)
    expected_return: float  # Expected annual investment return
    inflation_rate: float  # Expected inflation rate
    target_bracket: float  # Target marginal tax bracket to fill (e.g., 0.22)
    spouse_age: Optional[int] = None  # For MFJ, spouse's age
    
    def get_standard_deduction(self, year: int = 0) -> float:
        """Calculate standard deduction based on filing status and age."""
        inflation_factor = (1 + self.inflation_rate) ** year
        
        if self.filing_status == 'mfj':
            base = STANDARD_DEDUCTION_MFJ_2024
            extra = 0
            if self.age + year >= 65:
                extra += STANDARD_DEDUCTION_65_PLUS_ADDITION
            if self.spouse_age and self.spouse_age + year >= 65:
                extra += STANDARD_DEDUCTION_65_PLUS_ADDITION
        else:
            base = STANDARD_DEDUCTION_SINGLE_2024
            extra = STANDARD_DEDUCTION_65_PLUS_ADDITION if self.age + year >= 65 else 0
        
        return (base + extra) * inflation_factor
    
    def get_tax_brackets(self, year: int = 0) -> List[Tuple[float, float]]:
        """Get inflation-adjusted tax brackets."""
        inflation_factor = (1 + self.inflation_rate) ** year
        base_brackets = TAX_BRACKETS_MFJ_2024 if self.filing_status == 'mfj' else TAX_BRACKETS_SINGLE_2024
        
        adjusted_brackets = []
        for limit, rate in base_brackets:
            if limit == float('inf'):
                adjusted_brackets.append((limit, rate))
            else:
                adjusted_brackets.append((limit * inflation_factor, rate))
        
        return adjusted_brackets


# =============================================================================
# BUILD HOUSEHOLD FROM YOUR INPUT DATA
# =============================================================================

spouse1 = SpouseAccounts(
    name=SPOUSE1_NAME,
    age=SPOUSE1_AGE,
    traditional_ira=SPOUSE1_TRADITIONAL_IRA,
    sep_ira=SPOUSE1_SEP_IRA,
    roth_ira=SPOUSE1_ROTH_IRA,
    retirement_age=SPOUSE1_RETIREMENT_AGE,
    ss_start_age=SPOUSE1_SS_START_AGE,
    ss_annual_benefit=SPOUSE1_SS_ANNUAL,
)

spouse2 = SpouseAccounts(
    name=SPOUSE2_NAME,
    age=SPOUSE2_AGE,
    traditional_ira=SPOUSE2_TRADITIONAL_IRA,
    sep_ira=SPOUSE2_SEP_IRA,
    roth_ira=SPOUSE2_ROTH_IRA,
    retirement_age=SPOUSE2_RETIREMENT_AGE,
    ss_start_age=SPOUSE2_SS_START_AGE,
    ss_annual_benefit=SPOUSE2_SS_ANNUAL,
)

household = HouseholdProfile(
    spouse1=spouse1,
    spouse2=spouse2,
    joint_taxable_accounts=JOINT_TAXABLE_ACCOUNTS,
    work_income=CURRENT_WORK_INCOME,
    pension_income=PENSION_INCOME,
    other_income=OTHER_INCOME,
    state_tax_rate=STATE_TAX_RATE,
    expected_return=EXPECTED_RETURN,
    inflation_rate=INFLATION_RATE,
    target_bracket=TARGET_BRACKET,
)

# Display summary
print("=" * 70)
print("HOUSEHOLD RETIREMENT ACCOUNT SUMMARY")
print("=" * 70)
print(f"\n{spouse1.name} (Age {spouse1.age}):")
print(f"  Traditional IRA:    ${spouse1.traditional_ira:>12,.0f}")
print(f"  SEP-IRA:            ${spouse1.sep_ira:>12,.0f}")
print(f"  Roth IRA:           ${spouse1.roth_ira:>12,.0f}")
print(f"  Total Pre-Tax:      ${spouse1.total_pretax:>12,.0f}")
print(f"  Retirement Age:     {spouse1.retirement_age}")
print(f"  SS Start Age:       {spouse1.ss_start_age} (${spouse1.ss_annual_benefit:,.0f}/yr)")

print(f"\n{spouse2.name} (Age {spouse2.age}):")
print(f"  Traditional IRA:    ${spouse2.traditional_ira:>12,.0f}")
print(f"  SEP-IRA:            ${spouse2.sep_ira:>12,.0f}")
print(f"  Roth IRA:           ${spouse2.roth_ira:>12,.0f}")
print(f"  Total Pre-Tax:      ${spouse2.total_pretax:>12,.0f}")
print(f"  Retirement Age:     {spouse2.retirement_age}")
print(f"  SS Start Age:       {spouse2.ss_start_age} (${spouse2.ss_annual_benefit:,.0f}/yr)")

print(f"\nJoint Accounts:")
print(f"  Taxable Accounts:   ${household.joint_taxable_accounts:>12,.0f}")

print(f"\n" + "-" * 70)
print(f"HOUSEHOLD TOTALS:")
print(f"  Total Pre-Tax:      ${household.total_pretax:>12,.0f}")
print(f"  Total Roth:         ${household.total_roth:>12,.0f}")
print(f"  Total Taxable:      ${household.joint_taxable_accounts:>12,.0f}")
print(f"  GRAND TOTAL:        ${household.total_pretax + household.total_roth + household.joint_taxable_accounts:>12,.0f}")

print(f"\n" + "-" * 70)
print("INCOME TIMELINE (First 10 Years):")
print(f"{'Year':<6} {'Age1':<5} {'Age2':<5} {'Work':>12} {'SS1':>10} {'SS2':>10} {'Total':>12}")
print("-" * 70)
for yr in range(10):
    inc = household.get_income_for_year(yr)
    age1 = spouse1.age + yr
    age2 = spouse2.age + yr
    total = household.get_taxable_income_for_year(yr)
    print(f"{2025+yr:<6} {age1:<5} {age2:<5} ${inc['work_income']:>10,.0f} ${inc['spouse1_ss']:>8,.0f} ${inc['spouse2_ss']:>8,.0f} ${total:>10,.0f}")

# %% [markdown]
# ## 📊 Section 2: Basic Wealth Projections (25 Years)
# **What this shows:** How your three "buckets" (Taxable, IRA, Roth) grow over 25 years with different conversion amounts.

# %%
# =============================================================================
# TAX CALCULATION HELPER FUNCTIONS
# =============================================================================

def calculate_federal_tax(taxable_income: float, brackets: List[Tuple[float, float]]) -> float:
    """Calculate federal income tax based on taxable income and brackets."""
    if taxable_income <= 0:
        return 0
    
    tax = 0
    prev_limit = 0
    
    for limit, rate in brackets:
        if taxable_income <= prev_limit:
            break
        
        taxable_in_bracket = min(taxable_income, limit) - prev_limit
        if taxable_in_bracket > 0:
            tax += taxable_in_bracket * rate
        
        prev_limit = limit
    
    return tax


def get_marginal_rate(taxable_income: float, brackets: List[Tuple[float, float]]) -> float:
    """Get the marginal tax rate for a given taxable income."""
    prev_limit = 0
    for limit, rate in brackets:
        if taxable_income <= limit:
            return rate
        prev_limit = limit
    return brackets[-1][1]


def find_bracket_top_for_rate(target_rate: float, brackets: List[Tuple[float, float]]) -> float:
    """Find income at top of target bracket."""
    for limit, rate in brackets:
        if rate == target_rate:
            return limit
    # If not found, find limit before next higher rate
    prev_limit = 0
    for limit, rate in brackets:
        if rate > target_rate:
            return prev_limit
        prev_limit = limit
    return brackets[-2][0]


# =============================================================================
# HOUSEHOLD OPTIMIZATION FUNCTIONS
# =============================================================================

def calculate_household_tax(
    household: HouseholdProfile,
    total_conversion: float,
    year: int = 0
) -> Tuple[float, float, float]:
    """Calculate total tax for household with given conversion amount.
    
    Returns: (federal_tax, state_tax, total_tax)
    """
    standard_deduction = household.get_standard_deduction(year)
    brackets = household.get_tax_brackets(year)
    
    # Get year-specific income (accounts for retirement, SS timing)
    other_income = household.get_taxable_income_for_year(year)
    
    # Total gross income
    gross_income = other_income + total_conversion
    
    # Taxable income
    taxable_income = max(0, gross_income - standard_deduction)
    
    # Federal tax
    federal_tax = calculate_federal_tax(taxable_income, brackets)
    
    # State tax
    state_tax = taxable_income * household.state_tax_rate
    
    return federal_tax, state_tax, federal_tax + state_tax


def find_household_optimal_conversion(
    household: HouseholdProfile,
    year: int = 0
) -> Dict:
    """Find optimal conversion to fill target bracket for household."""
    standard_deduction = household.get_standard_deduction(year)
    brackets = household.get_tax_brackets(year)
    
    # Get year-specific income
    other_income = household.get_taxable_income_for_year(year)
    income_detail = household.get_income_for_year(year)
    
    # Current taxable income
    current_taxable = max(0, other_income - standard_deduction)
    current_marginal = get_marginal_rate(current_taxable, brackets)
    
    # Find bracket top
    bracket_top = find_bracket_top_for_rate(household.target_bracket, brackets)
    
    # Optimal conversion
    target_gross = bracket_top + standard_deduction
    optimal_conversion = max(0, target_gross - other_income)
    
    # Calculate tax
    fed_tax, state_tax, total_tax = calculate_household_tax(household, optimal_conversion, year)
    
    return {
        'year': year,
        'calendar_year': 2025 + year,
        'other_income': other_income,
        'work_income': income_detail['work_income'],
        'ss_income': income_detail['total_ss'],
        'standard_deduction': standard_deduction,
        'current_marginal_rate': current_marginal,
        'target_bracket': household.target_bracket,
        'bracket_top': bracket_top,
        'optimal_conversion': optimal_conversion,
        'federal_tax': fed_tax,
        'state_tax': state_tax,
        'total_tax': total_tax,
        'effective_rate': total_tax / optimal_conversion if optimal_conversion > 0 else 0
    }


def optimize_household_5_year(
    household: HouseholdProfile,
    years: int = 5
) -> pd.DataFrame:
    """Optimize household Roth conversions over 5 years.
    
    Allocates conversions between spouses based on their pre-tax balances.
    """
    results = []
    
    # Track each spouse's balances separately
    s1_pretax = household.spouse1.total_pretax
    s2_pretax = household.spouse2.total_pretax
    s1_roth = household.spouse1.roth_ira
    s2_roth = household.spouse2.roth_ira
    
    total_taxes = 0
    total_converted = 0
    
    for year in range(years):
        # Get optimal total conversion for household
        conv_info = find_household_optimal_conversion(household, year)
        
        # Total available pre-tax
        total_pretax = s1_pretax + s2_pretax
        
        # Cap at available balance
        total_conversion = min(conv_info['optimal_conversion'], total_pretax)
        
        # Allocate between spouses proportionally
        if total_pretax > 0:
            s1_ratio = s1_pretax / total_pretax
        else:
            s1_ratio = 0.5
        
        s1_conversion = total_conversion * s1_ratio
        s2_conversion = total_conversion * (1 - s1_ratio)
        
        # Recalculate tax for actual conversion
        fed_tax, state_tax, total_tax = calculate_household_tax(household, total_conversion, year)
        
        # Apply growth first
        growth = 1 + household.expected_return
        s1_pretax *= growth
        s2_pretax *= growth
        s1_roth *= growth
        s2_roth *= growth
        
        # Then do conversions
        s1_pretax -= s1_conversion
        s2_pretax -= s2_conversion
        s1_roth += s1_conversion
        s2_roth += s2_conversion
        
        total_taxes += total_tax
        total_converted += total_conversion
        
        # Get income details for display
        income_detail = household.get_income_for_year(year)
        
        results.append({
            'Year': year + 1,
            'Calendar_Year': 2025 + year,
            f'{household.spouse1.name}_Age': household.spouse1.age + year,
            f'{household.spouse2.name}_Age': household.spouse2.age + year,
            'Other_Income': conv_info['other_income'],
            'SS_Income': income_detail['total_ss'],
            'Total_Conversion': total_conversion,
            f'{household.spouse1.name}_Conversion': s1_conversion,
            f'{household.spouse2.name}_Conversion': s2_conversion,
            'Federal_Tax': fed_tax,
            'State_Tax': state_tax,
            'Total_Tax': total_tax,
            'Effective_Rate': (total_tax / total_conversion * 100) if total_conversion > 0 else 0,
            f'{household.spouse1.name}_PreTax': s1_pretax,
            f'{household.spouse2.name}_PreTax': s2_pretax,
            f'{household.spouse1.name}_Roth': s1_roth,
            f'{household.spouse2.name}_Roth': s2_roth,
            'Total_PreTax': s1_pretax + s2_pretax,
            'Total_Roth': s1_roth + s2_roth,
            'Cumulative_Converted': total_converted,
            'Cumulative_Taxes': total_taxes
        })
    
    return pd.DataFrame(results)


# Run optimization for household
household_plan = optimize_household_5_year(household, years=5)

print("=" * 80)
print("5-YEAR HOUSEHOLD ROTH CONVERSION PLAN")
print("=" * 80)

# Display key columns
display_cols = ['Calendar_Year', 'Other_Income', 'SS_Income', 'Total_Conversion', 
                f'{household.spouse1.name}_Conversion', f'{household.spouse2.name}_Conversion',
                'Total_Tax', 'Effective_Rate']
household_plan[display_cols]

# %%
# Detailed Summary
print("\n" + "=" * 80)
print("HOUSEHOLD 5-YEAR CONVERSION SUMMARY")
print("=" * 80)

print(f"\nStarting Balances:")
print(f"  {household.spouse1.name} Pre-Tax (IRA + SEP): ${household.spouse1.total_pretax:>12,.0f}")
print(f"  {household.spouse2.name} Pre-Tax (IRA + SEP): ${household.spouse2.total_pretax:>12,.0f}")
print(f"  Combined Pre-Tax:                  ${household.total_pretax:>12,.0f}")
print(f"  Combined Roth:                     ${household.total_roth:>12,.0f}")

print(f"\nConversion Results:")
print(f"  Total Converted:                   ${household_plan['Total_Conversion'].sum():>12,.0f}")
print(f"    {household.spouse1.name}:                          ${household_plan[f'{household.spouse1.name}_Conversion'].sum():>12,.0f}")
print(f"    {household.spouse2.name}:                            ${household_plan[f'{household.spouse2.name}_Conversion'].sum():>12,.0f}")
print(f"  Total Taxes Paid:                  ${household_plan['Total_Tax'].sum():>12,.0f}")
print(f"  Average Effective Rate:            {household_plan['Effective_Rate'].mean():>11.1f}%")

print(f"\nEnding Balances (Year 5):")
print(f"  {household.spouse1.name} Pre-Tax:                     ${household_plan[f'{household.spouse1.name}_PreTax'].iloc[-1]:>12,.0f}")
print(f"  {household.spouse2.name} Pre-Tax:                       ${household_plan[f'{household.spouse2.name}_PreTax'].iloc[-1]:>12,.0f}")
print(f"  {household.spouse1.name} Roth:                         ${household_plan[f'{household.spouse1.name}_Roth'].iloc[-1]:>12,.0f}")
print(f"  {household.spouse2.name} Roth:                           ${household_plan[f'{household.spouse2.name}_Roth'].iloc[-1]:>12,.0f}")
print(f"  Total Pre-Tax:                     ${household_plan['Total_PreTax'].iloc[-1]:>12,.0f}")
print(f"  Total Roth:                        ${household_plan['Total_Roth'].iloc[-1]:>12,.0f}")

# %% [markdown]
# ## 📊 Section 3: RMD Impact Charts
# **What these charts show:** How Roth conversions reduce your Required Minimum Distributions starting at age 73.

# %%
# =============================================================================
# RMD IMPACT ANALYSIS
# Compare RMDs with and without Roth conversions
# =============================================================================

def calculate_rmd_factor(age: int) -> float:
    """Get the RMD distribution period based on age (Uniform Lifetime Table)."""
    rmd_table = {
        73: 26.5, 74: 25.5, 75: 24.6, 76: 23.7, 77: 22.9,
        78: 22.0, 79: 21.1, 80: 20.2, 81: 19.4, 82: 18.5,
        83: 17.7, 84: 16.8, 85: 16.0, 86: 15.2, 87: 14.4,
        88: 13.7, 89: 12.9, 90: 12.2, 91: 11.5, 92: 10.8,
        93: 10.1, 94: 9.5, 95: 8.9, 96: 8.4, 97: 7.8,
        98: 7.3, 99: 6.8, 100: 6.4
    }
    if age < 73:
        return 0
    if age > 100:
        return 6.4
    return rmd_table.get(age, 6.4)


def project_rmd_comparison(household: HouseholdProfile, conversion_plan: pd.DataFrame, 
                           projection_years: int = 20) -> pd.DataFrame:
    """Project RMDs with and without conversion strategy."""
    
    # Starting balances
    s1_pretax_no_conv = household.spouse1.total_pretax
    s2_pretax_no_conv = household.spouse2.total_pretax
    
    # Get ending balances from conversion plan
    s1_pretax_with_conv = conversion_plan[f'{household.spouse1.name}_PreTax'].iloc[-1]
    s2_pretax_with_conv = conversion_plan[f'{household.spouse2.name}_PreTax'].iloc[-1]
    
    # Years already passed in conversion plan
    conversion_years = len(conversion_plan)
    
    results = []
    
    # Project forward from end of conversion period
    for year in range(projection_years):
        actual_year = conversion_years + year
        calendar_year = 2025 + actual_year
        
        s1_age = household.spouse1.age + actual_year
        s2_age = household.spouse2.age + actual_year
        
        # Growth (apply at start of year)
        growth = 1 + household.expected_return
        
        # WITHOUT conversions path (just grow from original, take RMDs)
        s1_pretax_no_conv *= growth
        s2_pretax_no_conv *= growth
        
        s1_rmd_factor = calculate_rmd_factor(s1_age)
        s2_rmd_factor = calculate_rmd_factor(s2_age)
        
        s1_rmd_no_conv = s1_pretax_no_conv / s1_rmd_factor if s1_rmd_factor > 0 else 0
        s2_rmd_no_conv = s2_pretax_no_conv / s2_rmd_factor if s2_rmd_factor > 0 else 0
        total_rmd_no_conv = s1_rmd_no_conv + s2_rmd_no_conv
        
        s1_pretax_no_conv -= s1_rmd_no_conv
        s2_pretax_no_conv -= s2_rmd_no_conv
        
        # WITH conversions path (grow from reduced balances, take RMDs)
        s1_pretax_with_conv *= growth
        s2_pretax_with_conv *= growth
        
        s1_rmd_with_conv = s1_pretax_with_conv / s1_rmd_factor if s1_rmd_factor > 0 else 0
        s2_rmd_with_conv = s2_pretax_with_conv / s2_rmd_factor if s2_rmd_factor > 0 else 0
        total_rmd_with_conv = s1_rmd_with_conv + s2_rmd_with_conv
        
        s1_pretax_with_conv -= s1_rmd_with_conv
        s2_pretax_with_conv -= s2_rmd_with_conv
        
        # RMD reduction
        rmd_reduction = total_rmd_no_conv - total_rmd_with_conv
        
        results.append({
            'Year': calendar_year,
            f'{household.spouse1.name}_Age': s1_age,
            f'{household.spouse2.name}_Age': s2_age,
            'RMD_Without_Conversion': total_rmd_no_conv,
            'RMD_With_Conversion': total_rmd_with_conv,
            'Annual_RMD_Reduction': rmd_reduction,
            'PreTax_Without_Conv': s1_pretax_no_conv + s2_pretax_no_conv,
            'PreTax_With_Conv': s1_pretax_with_conv + s2_pretax_with_conv,
        })
    
    return pd.DataFrame(results)


# Run RMD projection
rmd_projection = project_rmd_comparison(household, household_plan, projection_years=20)

# Filter to show only years where RMDs apply (age 73+)
rmd_years = rmd_projection[rmd_projection['RMD_Without_Conversion'] > 0].copy()

print("=" * 90)
print("RMD IMPACT ANALYSIS: With vs Without Roth Conversions")
print("=" * 90)

if len(rmd_years) > 0:
    print(f"\n{'Year':<6} {household.spouse1.name[:6]+'_Age':<10} {household.spouse2.name[:6]+'_Age':<10} {'RMD No Conv':>14} {'RMD With Conv':>14} {'Reduction':>12}")
    print("-" * 90)
    
    for _, row in rmd_years.head(15).iterrows():
        print(f"{int(row['Year']):<6} {int(row[f'{household.spouse1.name}_Age']):<10} {int(row[f'{household.spouse2.name}_Age']):<10} "
              f"${row['RMD_Without_Conversion']:>12,.0f} ${row['RMD_With_Conversion']:>12,.0f} ${row['Annual_RMD_Reduction']:>10,.0f}")
    
    # Summary
    total_rmd_reduction = rmd_years['Annual_RMD_Reduction'].sum()
    avg_annual_reduction = rmd_years['Annual_RMD_Reduction'].mean()
    first_rmd_year = rmd_years['Year'].iloc[0]
    
    print("\n" + "=" * 90)
    print("RMD REDUCTION SUMMARY")
    print("=" * 90)
    print(f"\nFirst RMD Year: {int(first_rmd_year)}")
    print(f"Total RMD Reduction (over {len(rmd_years)} years):  ${total_rmd_reduction:>12,.0f}")
    print(f"Average Annual RMD Reduction:                ${avg_annual_reduction:>12,.0f}")
    
    # Estimate tax savings on reduced RMDs (assuming 22% bracket)
    estimated_tax_savings = total_rmd_reduction * 0.22
    print(f"\nEstimated Tax Savings on Reduced RMDs (at 22%): ${estimated_tax_savings:>10,.0f}")
    
    # Compare to conversion taxes paid
    conversion_taxes_paid = household_plan['Total_Tax'].sum()
    print(f"Taxes Paid on Conversions:                       ${conversion_taxes_paid:>10,.0f}")
    print(f"Net Benefit (RMD tax savings - conversion tax):  ${estimated_tax_savings - conversion_taxes_paid:>10,.0f}")
else:
    print("\nNo RMDs projected yet - both spouses are under age 73 in projection period.")

# %%
# Visualize RMD Impact
if len(rmd_years) > 0:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Plot 1: RMD Comparison
    ax1 = axes[0]
    years = rmd_years['Year'].head(15)
    ax1.bar(years - 0.2, rmd_years['RMD_Without_Conversion'].head(15), 0.4, 
            label='Without Conversions', color='indianred', alpha=0.8)
    ax1.bar(years + 0.2, rmd_years['RMD_With_Conversion'].head(15), 0.4,
            label='With Conversions', color='mediumseagreen', alpha=0.8)
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Required Minimum Distribution ($)')
    ax1.set_title('Annual RMDs: With vs Without Roth Conversions')
    ax1.legend()
    ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45)
    
    # Plot 2: Cumulative RMD Reduction
    ax2 = axes[1]
    cumulative_reduction = rmd_years['Annual_RMD_Reduction'].cumsum()
    ax2.fill_between(rmd_years['Year'], 0, cumulative_reduction, 
                     alpha=0.6, color='mediumseagreen')
    ax2.plot(rmd_years['Year'], cumulative_reduction, 'o-', 
             color='darkgreen', linewidth=2, markersize=4)
    ax2.set_xlabel('Year')
    ax2.set_ylabel('Cumulative RMD Reduction ($)')
    ax2.set_title('Cumulative RMD Reduction from Conversions')
    ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('rmd_impact_analysis.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    print("\nChart saved as 'rmd_impact_analysis.png'")
else:
    print("No RMD chart - projection period doesn't reach RMD age.")

# %% [markdown]
# ## 📊 Section 4: Tax Bracket Strategy Comparison
# **What these charts show:** Comparing different conversion strategies (stay in 22%, 24%, or 32% bracket) to find optimal approach.

# %%
# =============================================================================
# BRACKET STRATEGY COMPARISON
# Compare: Current bracket, +1 bracket, +2 brackets
# =============================================================================

# Define the bracket progression for MFJ
BRACKET_ORDER = [0.10, 0.12, 0.22, 0.24, 0.32, 0.35, 0.37]

def get_next_brackets(current_bracket: float, steps: int = 1) -> float:
    """Get the bracket that is 'steps' higher than current."""
    try:
        current_idx = BRACKET_ORDER.index(current_bracket)
        new_idx = min(current_idx + steps, len(BRACKET_ORDER) - 1)
        return BRACKET_ORDER[new_idx]
    except ValueError:
        return current_bracket


def run_bracket_strategy(household: HouseholdProfile, target_bracket: float, 
                         years: int = 5, projection_years: int = 20) -> Dict:
    """Run a complete strategy for a given target bracket.
    
    Returns conversion plan, RMD projections, and summary metrics.
    """
    # Create a copy of household with new target bracket
    strategy_household = HouseholdProfile(
        spouse1=household.spouse1,
        spouse2=household.spouse2,
        joint_taxable_accounts=household.joint_taxable_accounts,
        work_income=household.work_income,
        pension_income=household.pension_income,
        other_income=household.other_income,
        state_tax_rate=household.state_tax_rate,
        expected_return=household.expected_return,
        inflation_rate=household.inflation_rate,
        target_bracket=target_bracket,
    )
    
    # Run 5-year conversion optimization
    plan = optimize_household_5_year(strategy_household, years=years)
    
    # Run RMD projection
    rmd_proj = project_rmd_comparison(strategy_household, plan, projection_years=projection_years)
    rmd_years_only = rmd_proj[rmd_proj['RMD_Without_Conversion'] > 0]
    
    # Calculate metrics
    total_converted = plan['Total_Conversion'].sum()
    total_conversion_tax = plan['Total_Tax'].sum()
    avg_conversion_rate = (total_conversion_tax / total_converted * 100) if total_converted > 0 else 0
    
    total_rmd_reduction = rmd_years_only['Annual_RMD_Reduction'].sum() if len(rmd_years_only) > 0 else 0
    
    # Estimate tax on reduced RMDs (use the target bracket as approximation)
    rmd_tax_savings = total_rmd_reduction * target_bracket
    
    # Net benefit = RMD tax savings - conversion taxes paid
    net_benefit = rmd_tax_savings - total_conversion_tax
    
    # Final balances
    final_pretax = plan['Total_PreTax'].iloc[-1]
    final_roth = plan['Total_Roth'].iloc[-1]
    
    return {
        'target_bracket': target_bracket,
        'bracket_pct': f"{int(target_bracket * 100)}%",
        'plan': plan,
        'rmd_projection': rmd_proj,
        'total_converted': total_converted,
        'total_conversion_tax': total_conversion_tax,
        'avg_conversion_rate': avg_conversion_rate,
        'total_rmd_reduction': total_rmd_reduction,
        'rmd_tax_savings': rmd_tax_savings,
        'net_benefit': net_benefit,
        'final_pretax': final_pretax,
        'final_roth': final_roth,
    }


def compare_bracket_strategies(household: HouseholdProfile) -> pd.DataFrame:
    """Compare current bracket, +1 bracket, and +2 bracket strategies."""
    
    # Determine current marginal bracket based on current income
    current_taxable = household.get_taxable_income_for_year(0)
    std_ded = household.get_standard_deduction(0)
    taxable = max(0, current_taxable - std_ded)
    
    # Find current bracket
    current_bracket = 0.10
    for limit, rate in TAX_BRACKETS_MFJ_2024:
        if taxable <= limit:
            current_bracket = rate
            break
    
    # Define strategies to compare
    strategies = {
        'No Conversion': 0.0,  # Special case
        f'Fill {int(current_bracket*100)}% (Current)': current_bracket,
        f'Fill {int(get_next_brackets(current_bracket, 1)*100)}% (+1 Bracket)': get_next_brackets(current_bracket, 1),
        f'Fill {int(get_next_brackets(current_bracket, 2)*100)}% (+2 Brackets)': get_next_brackets(current_bracket, 2),
    }
    
    results = []
    strategy_details = {}
    
    for name, bracket in strategies.items():
        if bracket == 0.0:
            # No conversion scenario
            results.append({
                'Strategy': name,
                'Target_Bracket': 'N/A',
                'Total_Converted': 0,
                'Conversion_Taxes': 0,
                'Avg_Conv_Rate': 0,
                'RMD_Reduction': 0,
                'Est_RMD_Tax_Savings': 0,
                'Net_Benefit': 0,
                'Final_PreTax': household.total_pretax * ((1 + household.expected_return) ** 5),
                'Final_Roth': household.total_roth * ((1 + household.expected_return) ** 5),
            })
        else:
            strategy = run_bracket_strategy(household, bracket)
            strategy_details[name] = strategy
            
            results.append({
                'Strategy': name,
                'Target_Bracket': strategy['bracket_pct'],
                'Total_Converted': strategy['total_converted'],
                'Conversion_Taxes': strategy['total_conversion_tax'],
                'Avg_Conv_Rate': strategy['avg_conversion_rate'],
                'RMD_Reduction': strategy['total_rmd_reduction'],
                'Est_RMD_Tax_Savings': strategy['rmd_tax_savings'],
                'Net_Benefit': strategy['net_benefit'],
                'Final_PreTax': strategy['final_pretax'],
                'Final_Roth': strategy['final_roth'],
            })
    
    return pd.DataFrame(results), strategy_details


# Run the comparison
print("=" * 100)
print("BRACKET STRATEGY COMPARISON")
print("=" * 100)
print("\nAnalyzing conversion strategies: Current bracket, +1 bracket, +2 brackets...")
print("This compares the cost of conversions now vs. the RMD tax savings later.\n")

comparison_df, strategy_details = compare_bracket_strategies(household)

# Display summary table
print("=" * 100)
print("STRATEGY SUMMARY (5-Year Conversion Period + 20-Year RMD Projection)")
print("=" * 100)
comparison_df

# %%
# Detailed breakdown
print("\n" + "=" * 100)
print("DETAILED COMPARISON")
print("=" * 100)

for _, row in comparison_df.iterrows():
    print(f"\n📌 {row['Strategy']}")
    print(f"   Total Converted (5 years):     ${row['Total_Converted']:>12,.0f}")
    print(f"   Taxes Paid on Conversions:     ${row['Conversion_Taxes']:>12,.0f}  (avg {row['Avg_Conv_Rate']:.1f}%)")
    print(f"   RMD Reduction (20 years):      ${row['RMD_Reduction']:>12,.0f}")
    print(f"   Est. Tax Savings on RMDs:      ${row['Est_RMD_Tax_Savings']:>12,.0f}")
    print(f"   ─────────────────────────────────────────")
    print(f"   NET BENEFIT:                   ${row['Net_Benefit']:>12,.0f}  {'✅ GAIN' if row['Net_Benefit'] > 0 else '❌ LOSS' if row['Net_Benefit'] < 0 else ''}")

# Find the best strategy
best_strategy = comparison_df.loc[comparison_df['Net_Benefit'].idxmax()]
print("\n" + "=" * 100)
print(f"🏆 RECOMMENDED: {best_strategy['Strategy']}")
print(f"   This strategy provides the highest net benefit of ${best_strategy['Net_Benefit']:,.0f}")
print("=" * 100)

# %%
# =============================================================================
# VISUALIZATION: Bracket Strategy Comparison
# =============================================================================

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

strategies = comparison_df['Strategy'].tolist()
x = np.arange(len(strategies))

# Plot 1: Conversion Amount vs Taxes Paid
ax1 = axes[0, 0]
width = 0.35
bars1 = ax1.bar(x - width/2, comparison_df['Total_Converted'], width, 
                label='Amount Converted', color='steelblue', alpha=0.8)
bars2 = ax1.bar(x + width/2, comparison_df['Conversion_Taxes'], width,
                label='Taxes Paid', color='indianred', alpha=0.8)
ax1.set_ylabel('Amount ($)')
ax1.set_title('5-Year Conversions: Amount vs Taxes')
ax1.set_xticks(x)
ax1.set_xticklabels([s.replace(' ', '\n') for s in strategies], fontsize=8)
ax1.legend()
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# Plot 2: RMD Reduction & Tax Savings
ax2 = axes[0, 1]
bars3 = ax2.bar(x - width/2, comparison_df['RMD_Reduction'], width,
                label='RMD Reduction', color='mediumseagreen', alpha=0.8)
bars4 = ax2.bar(x + width/2, comparison_df['Est_RMD_Tax_Savings'], width,
                label='Est. Tax Savings', color='gold', alpha=0.8)
ax2.set_ylabel('Amount ($)')
ax2.set_title('20-Year RMD Impact')
ax2.set_xticks(x)
ax2.set_xticklabels([s.replace(' ', '\n') for s in strategies], fontsize=8)
ax2.legend()
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# Plot 3: Net Benefit (the key chart!)
ax3 = axes[1, 0]
colors = ['gray' if v == 0 else ('green' if v > 0 else 'red') for v in comparison_df['Net_Benefit']]
bars5 = ax3.bar(x, comparison_df['Net_Benefit'], color=colors, alpha=0.8, edgecolor='black')
ax3.axhline(y=0, color='black', linestyle='-', linewidth=0.5)
ax3.set_ylabel('Net Benefit ($)')
ax3.set_title('💰 NET BENEFIT: RMD Tax Savings - Conversion Taxes')
ax3.set_xticks(x)
ax3.set_xticklabels([s.replace(' ', '\n') for s in strategies], fontsize=8)
ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# Add value labels on net benefit bars
for bar, val in zip(bars5, comparison_df['Net_Benefit']):
    height = bar.get_height()
    ax3.text(bar.get_x() + bar.get_width()/2., height,
             f'${val/1000:.0f}K',
             ha='center', va='bottom' if height >= 0 else 'top',
             fontsize=10, fontweight='bold')

# Plot 4: Final Account Balances
ax4 = axes[1, 1]
bars6 = ax4.bar(x - width/2, comparison_df['Final_PreTax'], width,
                label='Pre-Tax (will be taxed)', color='coral', alpha=0.8)
bars7 = ax4.bar(x + width/2, comparison_df['Final_Roth'], width,
                label='Roth (tax-free)', color='mediumseagreen', alpha=0.8)
ax4.set_ylabel('Balance After 5 Years ($)')
ax4.set_title('Final Account Balances')
ax4.set_xticks(x)
ax4.set_xticklabels([s.replace(' ', '\n') for s in strategies], fontsize=8)
ax4.legend()
ax4.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

plt.tight_layout()
plt.savefig('bracket_strategy_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'bracket_strategy_comparison.png'")

# %%
# =============================================================================
# YEAR-BY-YEAR COMPARISON ACROSS STRATEGIES
# =============================================================================

# Show annual conversion amounts for each strategy
print("=" * 100)
print("ANNUAL CONVERSION AMOUNTS BY STRATEGY")
print("=" * 100)

# Build comparison table
annual_comparison = pd.DataFrame({'Year': range(2025, 2030)})

for name, details in strategy_details.items():
    annual_comparison[name] = details['plan']['Total_Conversion'].values

print(annual_comparison.to_string(index=False, formatters={
    col: '${:,.0f}'.format for col in annual_comparison.columns if col != 'Year'
}))

# Calculate annual taxes for each strategy
print("\n" + "=" * 100)
print("ANNUAL TAXES BY STRATEGY")
print("=" * 100)

tax_comparison = pd.DataFrame({'Year': range(2025, 2030)})
for name, details in strategy_details.items():
    tax_comparison[name] = details['plan']['Total_Tax'].values

print(tax_comparison.to_string(index=False, formatters={
    col: '${:,.0f}'.format for col in tax_comparison.columns if col != 'Year'
}))

# %%
# =============================================================================
# RMD COMPARISON CHART ACROSS STRATEGIES
# =============================================================================

fig, ax = plt.subplots(figsize=(14, 6))

# Get RMD projections for each strategy
colors = ['gray', 'steelblue', 'orange', 'green']
linestyles = ['-', '-', '--', ':']

for i, (name, details) in enumerate(strategy_details.items()):
    rmd_data = details['rmd_projection']
    rmd_with_conv = rmd_data[rmd_data['RMD_With_Conversion'] > 0]
    if len(rmd_with_conv) > 0:
        ax.plot(rmd_with_conv['Year'], rmd_with_conv['RMD_With_Conversion'], 
                label=name, color=colors[i+1], linestyle=linestyles[i+1], 
                linewidth=2, marker='o', markersize=4)

# Also plot "no conversion" scenario (RMD without conversion)
if len(strategy_details) > 0:
    first_strategy = list(strategy_details.values())[0]
    rmd_data = first_strategy['rmd_projection']
    rmd_no_conv = rmd_data[rmd_data['RMD_Without_Conversion'] > 0]
    if len(rmd_no_conv) > 0:
        ax.plot(rmd_no_conv['Year'], rmd_no_conv['RMD_Without_Conversion'],
                label='No Conversion', color='indianred', linestyle='-',
                linewidth=3, marker='s', markersize=5)

ax.set_xlabel('Year')
ax.set_ylabel('Required Minimum Distribution ($)')
ax.set_title('RMD Amounts Over Time: Impact of Different Conversion Strategies')
ax.legend(loc='upper left')
ax.grid(True, alpha=0.3)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

plt.tight_layout()
plt.savefig('rmd_strategy_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'rmd_strategy_comparison.png'")

# %% [markdown]
# ## 📊 Section 5: Income-Guaranteed Optimization
# **What this does:** Finds the optimal conversion strategy that:
# - Guarantees your $11,000/month income
# - Maintains $75,000 cash reserve
# - Maximizes after-tax wealth over 25 years
#
# This is the MAIN optimizer that produces your recommended conversion plan.

# %%
# =============================================================================
# OPTIMAL CONVERSION CALCULATOR - WITH GUARANTEED INCOME
# Ensures $11K/month income, then maximizes after-tax wealth
# =============================================================================

# Capital gains tax rate for taxable account (long-term)
CAPITAL_GAINS_RATE = 0.15
# Dividend yield (portion of return that's taxable each year in taxable account)
DIVIDEND_YIELD = 0.02


def calculate_income_sources(
    household: HouseholdProfile,
    year: int,
    s1_pretax: float,
    s2_pretax: float,
    s1_roth: float,
    s2_roth: float,
    taxable: float,
    annual_income_need: float,
    inflation_rate: float
) -> Dict:
    """
    Calculate where income comes from to meet the annual need.
    
    Priority: SS → RMDs → Additional IRA Withdrawal → Taxable Withdrawal
    
    Returns dict with income sources and remaining balances.
    """
    # Inflation-adjust the income need
    income_need = annual_income_need * ((1 + inflation_rate) ** year)
    
    s1_age = household.spouse1.age + year
    s2_age = household.spouse2.age + year
    
    # 1. Social Security (if collecting)
    ss1 = household.spouse1.get_ss_income(year, inflation_rate)
    ss2 = household.spouse2.get_ss_income(year, inflation_rate)
    total_ss = ss1 + ss2
    
    # 2. Calculate RMDs (required regardless of income need)
    s1_rmd_factor = calculate_rmd_factor(s1_age)
    s2_rmd_factor = calculate_rmd_factor(s2_age)
    s1_rmd = s1_pretax / s1_rmd_factor if s1_rmd_factor > 0 else 0
    s2_rmd = s2_pretax / s2_rmd_factor if s2_rmd_factor > 0 else 0
    total_rmd = s1_rmd + s2_rmd
    
    # RMDs are withdrawn from IRA
    s1_pretax -= s1_rmd
    s2_pretax -= s2_rmd
    
    # Income so far
    income_from_ss = total_ss
    income_from_rmd = total_rmd
    income_so_far = income_from_ss + income_from_rmd
    
    # 3. Additional IRA withdrawal if needed (beyond RMD)
    additional_ira_withdrawal = 0
    if income_so_far < income_need:
        shortfall = income_need - income_so_far
        available_ira = s1_pretax + s2_pretax
        additional_ira_withdrawal = min(shortfall, available_ira)
        # Withdraw proportionally from each spouse
        if available_ira > 0:
            s1_pretax -= additional_ira_withdrawal * (s1_pretax / available_ira) if available_ira > 0 else 0
            s2_pretax -= additional_ira_withdrawal * (s2_pretax / available_ira) if available_ira > 0 else 0
        income_so_far += additional_ira_withdrawal
    
    # 4. Taxable account withdrawal if still short
    taxable_withdrawal = 0
    if income_so_far < income_need:
        shortfall = income_need - income_so_far
        taxable_withdrawal = min(shortfall, max(0, taxable))
        taxable -= taxable_withdrawal
        income_so_far += taxable_withdrawal
    
    # 5. Roth withdrawal as last resort (shouldn't need this normally)
    roth_withdrawal = 0
    if income_so_far < income_need:
        shortfall = income_need - income_so_far
        available_roth = s1_roth + s2_roth
        roth_withdrawal = min(shortfall, available_roth)
        if available_roth > 0:
            s1_roth -= roth_withdrawal * (s1_roth / available_roth) if available_roth > 0 else 0
            s2_roth -= roth_withdrawal * (s2_roth / available_roth) if available_roth > 0 else 0
        income_so_far += roth_withdrawal
    
    return {
        'income_need': income_need,
        'income_from_ss': income_from_ss,
        'income_from_rmd': income_from_rmd,
        'additional_ira_withdrawal': additional_ira_withdrawal,
        'taxable_withdrawal': taxable_withdrawal,
        'roth_withdrawal': roth_withdrawal,
        'total_income': income_so_far,
        'income_shortfall': max(0, income_need - income_so_far),
        's1_pretax': s1_pretax,
        's2_pretax': s2_pretax,
        's1_roth': s1_roth,
        's2_roth': s2_roth,
        'taxable': taxable,
        's1_rmd': s1_rmd,
        's2_rmd': s2_rmd,
    }


def calculate_wealth_with_income(
    conversion_amounts: List[float],
    household: HouseholdProfile,
    taxable_balance: float,
    annual_income_need: float,
    conversion_years: int = 5,
    projection_years: int = 25
) -> Dict:
    """
    Calculate wealth while guaranteeing income requirement each year.
    
    Conversions only happen if there's enough in taxable to:
    1. Pay the conversion tax
    2. Still meet income needs
    """
    # Track balances by bucket
    s1_pretax = household.spouse1.total_pretax
    s2_pretax = household.spouse2.total_pretax
    s1_roth = household.spouse1.roth_ira
    s2_roth = household.spouse2.roth_ira
    taxable = taxable_balance
    taxable_cost_basis = taxable_balance * 0.5
    
    total_conversion_taxes = 0
    total_income_taxes = 0
    yearly_data = []
    total_income_shortfall = 0
    
    for year in range(projection_years):
        s1_age = household.spouse1.age + year
        s2_age = household.spouse2.age + year
        
        # Apply growth at START of year (before withdrawals/conversions)
        s1_pretax *= (1 + IRA_RETURN)
        s2_pretax *= (1 + IRA_RETURN)
        s1_roth *= (1 + ROTH_RETURN)
        s2_roth *= (1 + ROTH_RETURN)
        
        # Taxable growth (with dividend tax drag)
        taxable_growth = taxable * TAXABLE_RETURN
        dividend_income = taxable * DIVIDEND_YIELD
        dividend_tax = dividend_income * CAPITAL_GAINS_RATE
        taxable = taxable + taxable_growth - dividend_tax
        taxable_cost_basis += (dividend_income - dividend_tax)
        
        # --- STEP 1: HANDLE INCOME NEEDS FIRST ---
        income_result = calculate_income_sources(
            household, year,
            s1_pretax, s2_pretax, s1_roth, s2_roth, taxable,
            annual_income_need, household.inflation_rate
        )
        
        # Update balances after income withdrawals
        s1_pretax = income_result['s1_pretax']
        s2_pretax = income_result['s2_pretax']
        s1_roth = income_result['s1_roth']
        s2_roth = income_result['s2_roth']
        taxable = income_result['taxable']
        total_income_shortfall += income_result['income_shortfall']
        
        # Calculate tax on income (SS + RMD + additional IRA withdrawal)
        taxable_income = (income_result['income_from_ss'] * 0.85 +  # 85% of SS taxable
                         income_result['income_from_rmd'] + 
                         income_result['additional_ira_withdrawal'])
        std_ded = household.get_standard_deduction(year)
        brackets = household.get_tax_brackets(year)
        income_taxable = max(0, taxable_income - std_ded)
        income_tax = calculate_federal_tax(income_taxable, brackets)
        income_tax += income_taxable * household.state_tax_rate
        total_income_taxes += income_tax
        
        # Pay income tax from taxable account
        taxable -= income_tax
        
        # --- STEP 2: ROTH CONVERSION (only during conversion years) ---
        conversion = 0
        conv_tax = 0
        s1_conv = 0
        s2_conv = 0
        
        if year < conversion_years and year < len(conversion_amounts):
            proposed_conversion = conversion_amounts[year]
            
            # Calculate tax on conversion
            if proposed_conversion > 0:
                # Tax is on top of already-taxed income
                combined_taxable = income_taxable + proposed_conversion
                combined_tax = calculate_federal_tax(combined_taxable, brackets)
                combined_tax += combined_taxable * household.state_tax_rate
                conv_tax = combined_tax - income_tax  # Incremental tax from conversion
                
                # Can we afford the conversion? Need enough in taxable to pay tax
                total_pretax = s1_pretax + s2_pretax
                max_conversion = min(proposed_conversion, total_pretax)
                
                # Only convert if we can pay the tax from taxable
                if taxable >= conv_tax and max_conversion > 0:
                    conversion = max_conversion
                    
                    # Split between spouses proportionally
                    if total_pretax > 0:
                        s1_ratio = s1_pretax / total_pretax
                        s1_conv = conversion * s1_ratio
                        s2_conv = conversion * (1 - s1_ratio)
                    
                    # Execute conversion
                    s1_pretax -= s1_conv
                    s2_pretax -= s2_conv
                    s1_roth += s1_conv
                    s2_roth += s2_conv
                    
                    # Pay conversion tax from taxable
                    taxable -= conv_tax
                    total_conversion_taxes += conv_tax
                else:
                    conv_tax = 0  # Can't afford it
        
        yearly_data.append({
            'year': year,
            'calendar_year': 2025 + year,
            's1_age': s1_age,
            's2_age': s2_age,
            # Income
            'income_need': income_result['income_need'],
            'income_from_ss': income_result['income_from_ss'],
            'income_from_rmd': income_result['income_from_rmd'],
            'additional_ira_withdrawal': income_result['additional_ira_withdrawal'],
            'taxable_withdrawal': income_result['taxable_withdrawal'],
            'roth_withdrawal': income_result['roth_withdrawal'],
            'total_income': income_result['total_income'],
            'income_shortfall': income_result['income_shortfall'],
            'income_tax': income_tax,
            # Conversion
            'conversion': conversion,
            's1_conv': s1_conv,
            's2_conv': s2_conv,
            'conv_tax': conv_tax,
            # Balances
            's1_pretax': s1_pretax,
            's2_pretax': s2_pretax,
            's1_roth': s1_roth,
            's2_roth': s2_roth,
            'taxable': taxable,
            'total_balance': s1_pretax + s2_pretax + s1_roth + s2_roth + taxable,
        })
    
    # Calculate after-tax wealth at end
    final_pretax = s1_pretax + s2_pretax
    final_roth = s1_roth + s2_roth
    final_taxable = taxable
    
    # Track minimum taxable balance (to check if it ever goes negative)
    min_taxable = min(d['taxable'] for d in yearly_data)
    first_negative_year = None
    for d in yearly_data:
        if d['taxable'] < 0:
            first_negative_year = d['calendar_year']
            break
    
    estimated_pretax_tax_rate = 0.22 + household.state_tax_rate
    pretax_after_tax_value = final_pretax * (1 - estimated_pretax_tax_rate)
    
    taxable_gains = max(0, final_taxable - taxable_cost_basis)
    taxable_after_tax_value = final_taxable - (taxable_gains * CAPITAL_GAINS_RATE)
    
    roth_after_tax_value = final_roth
    
    total_after_tax_wealth = pretax_after_tax_value + roth_after_tax_value + taxable_after_tax_value
    
    return {
        'total_conversion_taxes': total_conversion_taxes,
        'total_income_taxes': total_income_taxes,
        'total_income_shortfall': total_income_shortfall,
        'min_taxable_balance': min_taxable,
        'first_negative_year': first_negative_year,
        'final_pretax': final_pretax,
        'final_roth': final_roth,
        'final_taxable': final_taxable,
        'pretax_after_tax_value': pretax_after_tax_value,
        'roth_after_tax_value': roth_after_tax_value,
        'taxable_after_tax_value': taxable_after_tax_value,
        'total_after_tax_wealth': total_after_tax_wealth,
        'yearly_data': yearly_data,
    }


def optimize_with_income_guarantee(
    household: HouseholdProfile,
    taxable_balance: float,
    annual_income_need: float,
    min_cash_reserve: float = 0,
    conversion_years: int = 5,
    projection_years: int = 25,
    max_annual_conversion: float = None
) -> Tuple[List[float], Dict]:
    """
    Find optimal conversions that MAXIMIZE wealth while GUARANTEEING income.
    Also ensures taxable account stays above minimum cash reserve.
    """
    if max_annual_conversion is None:
        max_annual_conversion = household.total_pretax / conversion_years * 2
    
    def objective(conversions):
        result = calculate_wealth_with_income(
            list(conversions), household, taxable_balance, 
            annual_income_need, conversion_years, projection_years
        )
        # Penalize any income shortfall heavily
        penalty = result['total_income_shortfall'] * 1000
        # PENALIZE IF TAXABLE FALLS BELOW MINIMUM CASH RESERVE
        # This ensures you always have cash on hand
        if result['min_taxable_balance'] < min_cash_reserve:
            penalty += abs(result['min_taxable_balance'] - min_cash_reserve) * 100
        # Maximize wealth (minimize negative)
        return -result['total_after_tax_wealth'] + penalty
    
    bounds = [(0, max_annual_conversion) for _ in range(conversion_years)]
    
    print("🔄 Running optimization with GUARANTEED $11K/month income...")
    print(f"   Annual income need: ${annual_income_need:,.0f} (inflation-adjusted each year)")
    print(f"   Minimum cash reserve: ${min_cash_reserve:,.0f}")
    print(f"   Optimizing over {projection_years}-year projection...")
    
    result = differential_evolution(
        objective,
        bounds,
        seed=42,
        maxiter=500,
        tol=1e-6,
        workers=1,
        updating='deferred',
        polish=True,
    )
    
    optimal_conversions = list(result.x)
    optimal_outcome = calculate_wealth_with_income(
        optimal_conversions, household, taxable_balance,
        annual_income_need, conversion_years, projection_years
    )
    
    return optimal_conversions, optimal_outcome


# =============================================================================
# RUN THE OPTIMIZATION
# =============================================================================

print("=" * 100)
print("🎯 OPTIMIZING WITH GUARANTEED $11K/MONTH INCOME")
print("=" * 100)

print(f"\n💰 INCOME REQUIREMENT: ${MONTHLY_INCOME_NEED:,}/month = ${ANNUAL_INCOME_NEED:,}/year")
print(f"   (Will increase with {INFLATION_RATE*100:.1f}% inflation each year)")

print(f"\nStarting balances:")
print(f"  Taxable (Post-Tax):     ${JOINT_TAXABLE_ACCOUNTS:>12,.0f}  @ {TAXABLE_RETURN*100:.1f}% return")
print(f"  Traditional IRA:        ${household.total_pretax:>12,.0f}  @ {IRA_RETURN*100:.1f}% return")
print(f"  Roth IRA:               ${household.total_roth:>12,.0f}  @ {ROTH_RETURN*100:.1f}% return")
print(f"\n💵 Minimum Cash Reserve:  ${MINIMUM_CASH_RESERVE:>12,.0f}")

optimal_conversions, optimal_outcome = optimize_with_income_guarantee(
    household, 
    JOINT_TAXABLE_ACCOUNTS,
    ANNUAL_INCOME_NEED,
    min_cash_reserve=MINIMUM_CASH_RESERVE,
    conversion_years=5, 
    projection_years=25
)

# Also calculate "no conversion" scenario
no_conv_outcome = calculate_wealth_with_income(
    [0]*5, household, JOINT_TAXABLE_ACCOUNTS, ANNUAL_INCOME_NEED, 5, 25
)

print("\n✅ Optimization complete!")
if optimal_outcome['total_income_shortfall'] > 0:
    print(f"⚠️  WARNING: Income shortfall of ${optimal_outcome['total_income_shortfall']:,.0f} detected!")
else:
    print("✅ All income needs met for 25 years!")

# Check taxable account sustainability
if optimal_outcome['min_taxable_balance'] < MINIMUM_CASH_RESERVE:
    print(f"⚠️  WARNING: Taxable account falls below ${MINIMUM_CASH_RESERVE:,.0f} cash reserve!")
    print(f"   Minimum balance: ${optimal_outcome['min_taxable_balance']:,.0f}")
    if optimal_outcome['first_negative_year']:
        print(f"   First year below reserve: {optimal_outcome['first_negative_year']}")
    print(f"   Consider reducing conversions or increasing taxable balance.")
else:
    print(f"✅ Taxable account stays above ${MINIMUM_CASH_RESERVE:,.0f} reserve (minimum: ${optimal_outcome['min_taxable_balance']:,.0f})")

# %%
# =============================================================================
# DISPLAY INCOME ANALYSIS - GUARANTEED $11K/MONTH
# =============================================================================

print("=" * 100)
print("💵 GUARANTEED INCOME ANALYSIS - $11K/MONTH")
print("=" * 100)

# Show income sources for first 15 years
optimal_yearly = pd.DataFrame(optimal_outcome['yearly_data'])

print("\n📊 INCOME SOURCES BY YEAR (Inflation-Adjusted):")
print("-" * 120)
print(f"{'Year':<6} {'Ages':<10} {'Income Need':>14} {'From SS':>12} {'From RMD':>12} {'Add IRA WD':>12} {'Taxable WD':>12} {'Roth WD':>10} {'Shortfall':>12}")
print("-" * 120)

for i, row in optimal_yearly.head(15).iterrows():
    shortfall_flag = "⚠️" if row['income_shortfall'] > 0 else ""
    print(f"{row['calendar_year']:<6} {row['s1_age']}/{row['s2_age']:<6} "
          f"${row['income_need']:>12,.0f} ${row['income_from_ss']:>10,.0f} ${row['income_from_rmd']:>10,.0f} "
          f"${row['additional_ira_withdrawal']:>10,.0f} ${row['taxable_withdrawal']:>10,.0f} "
          f"${row['roth_withdrawal']:>8,.0f} ${row['income_shortfall']:>10,.0f} {shortfall_flag}")

if len(optimal_yearly) > 15:
    print(f"... ({len(optimal_yearly) - 15} more years)")

print("-" * 120)
total_income_drawn = (optimal_yearly['income_from_ss'].sum() + 
                     optimal_yearly['income_from_rmd'].sum() + 
                     optimal_yearly['additional_ira_withdrawal'].sum() +
                     optimal_yearly['taxable_withdrawal'].sum() +
                     optimal_yearly['roth_withdrawal'].sum())
print(f"TOTAL INCOME OVER 25 YEARS: ${total_income_drawn:,.0f}")
if optimal_outcome['total_income_shortfall'] > 0:
    print(f"⚠️  TOTAL INCOME SHORTFALL: ${optimal_outcome['total_income_shortfall']:,.0f}")
else:
    print("✅ ALL INCOME NEEDS MET!")

# =============================================================================
# DISPLAY OPTIMAL CONVERSION PLAN
# =============================================================================

print("\n" + "=" * 100)
print("🎯 YOUR OPTIMAL 5-YEAR ROTH CONVERSION PLAN")
print("=" * 100)

# Calculate spouse allocations
total_pretax_start = household.total_pretax
s1_ratio = household.spouse1.total_pretax / total_pretax_start
s2_ratio = household.spouse2.total_pretax / total_pretax_start

print("\n📋 RECOMMENDED ANNUAL CONVERSIONS:")
print("-" * 100)
print(f"{'Year':<6} {household.spouse1.name[:8]:<10} {household.spouse2.name[:8]:<10} {'Total Conv':>14} {household.spouse1.name[:6]+'_Conv':>12} {household.spouse2.name[:6]+'_Conv':>12} {'Tax':>12} {'Rate':>8}")
print("-" * 100)

for i in range(5):
    row = optimal_yearly.iloc[i]
    rate = row['conv_tax'] / row['conversion'] * 100 if row['conversion'] > 0 else 0
    print(f"{row['calendar_year']:<6} {row['s1_age']:<10} {row['s2_age']:<10} "
          f"${row['conversion']:>12,.0f} ${row['s1_conv']:>10,.0f} ${row['s2_conv']:>10,.0f} "
          f"${row['conv_tax']:>10,.0f} {rate:>6.1f}%")

print("-" * 100)
total_conv = sum(optimal_conversions)
print(f"{'TOTAL':<6} {'':<10} {'':<10} ${total_conv:>12,.0f} "
      f"${total_conv*s1_ratio:>10,.0f} ${total_conv*s2_ratio:>10,.0f} "
      f"${optimal_outcome['total_conversion_taxes']:>10,.0f} "
      f"{optimal_outcome['total_conversion_taxes']/total_conv*100 if total_conv > 0 else 0:>6.1f}%")

# =============================================================================
# WEALTH COMPARISON
# =============================================================================

print("\n" + "=" * 100)
print("💰 AFTER-TAX WEALTH COMPARISON (25 Years)")
print("=" * 100)

print(f"\n{'Bucket':<25} {'No Conversion':>18} {'Optimal Plan':>18} {'Difference':>15}")
print("-" * 80)
print(f"{'Taxable (Post-Tax)':<25} ${no_conv_outcome['final_taxable']:>16,.0f} ${optimal_outcome['final_taxable']:>16,.0f} ${optimal_outcome['final_taxable'] - no_conv_outcome['final_taxable']:>13,.0f}")
print(f"{'Traditional IRA (Pre-Tax)':<25} ${no_conv_outcome['final_pretax']:>16,.0f} ${optimal_outcome['final_pretax']:>16,.0f} ${optimal_outcome['final_pretax'] - no_conv_outcome['final_pretax']:>13,.0f}")
print(f"{'Roth IRA (Tax-Free)':<25} ${no_conv_outcome['final_roth']:>16,.0f} ${optimal_outcome['final_roth']:>16,.0f} ${optimal_outcome['final_roth'] - no_conv_outcome['final_roth']:>13,.0f}")
print("-" * 80)
print(f"{'TOTAL BALANCES':<25} ${no_conv_outcome['final_taxable'] + no_conv_outcome['final_pretax'] + no_conv_outcome['final_roth']:>16,.0f} ${optimal_outcome['final_taxable'] + optimal_outcome['final_pretax'] + optimal_outcome['final_roth']:>16,.0f}")

print(f"\n{'AFTER-TAX VALUES:':<25}")
print("-" * 80)
print(f"{'Taxable (less cap gains)':<25} ${no_conv_outcome['taxable_after_tax_value']:>16,.0f} ${optimal_outcome['taxable_after_tax_value']:>16,.0f} ${optimal_outcome['taxable_after_tax_value'] - no_conv_outcome['taxable_after_tax_value']:>13,.0f}")
print(f"{'IRA (less ~26% tax)':<25} ${no_conv_outcome['pretax_after_tax_value']:>16,.0f} ${optimal_outcome['pretax_after_tax_value']:>16,.0f} ${optimal_outcome['pretax_after_tax_value'] - no_conv_outcome['pretax_after_tax_value']:>13,.0f}")
print(f"{'Roth (100% tax-free)':<25} ${no_conv_outcome['roth_after_tax_value']:>16,.0f} ${optimal_outcome['roth_after_tax_value']:>16,.0f} ${optimal_outcome['roth_after_tax_value'] - no_conv_outcome['roth_after_tax_value']:>13,.0f}")
print("=" * 80)
print(f"{'TOTAL AFTER-TAX WEALTH':<25} ${no_conv_outcome['total_after_tax_wealth']:>16,.0f} ${optimal_outcome['total_after_tax_wealth']:>16,.0f} ${optimal_outcome['total_after_tax_wealth'] - no_conv_outcome['total_after_tax_wealth']:>13,.0f}")

wealth_gain = optimal_outcome['total_after_tax_wealth'] - no_conv_outcome['total_after_tax_wealth']
print(f"\n🏆 TOTAL WEALTH GAIN FROM OPTIMAL CONVERSIONS: ${wealth_gain:,.0f}")

# %%
# =============================================================================
# RMD COMPARISON: OPTIMAL vs NO CONVERSION
# =============================================================================

optimal_yearly_df = pd.DataFrame(optimal_outcome['yearly_data'])
no_conv_yearly_df = pd.DataFrame(no_conv_outcome['yearly_data'])

# Find years with RMDs
rmd_comparison = pd.DataFrame({
    'Year': optimal_yearly_df['calendar_year'],
    f'{household.spouse1.name}_Age': optimal_yearly_df['s1_age'],
    f'{household.spouse2.name}_Age': optimal_yearly_df['s2_age'],
    'RMD_No_Conversion': no_conv_yearly_df['income_from_rmd'],
    'RMD_With_Optimal': optimal_yearly_df['income_from_rmd'],
    'RMD_Reduction': no_conv_yearly_df['income_from_rmd'] - optimal_yearly_df['income_from_rmd'],
})

rmd_only = rmd_comparison[rmd_comparison['RMD_No_Conversion'] > 0].copy()

print("=" * 100)
print("📉 RMD REDUCTION ANALYSIS")
print("=" * 100)

if len(rmd_only) > 0:
    print(f"\n{'Year':<6} {household.spouse1.name[:6]:<7} {household.spouse2.name[:6]:<7} {'RMD No Conv':>14} {'RMD Optimal':>14} {'Reduction':>12} {'% Reduction':>12}")
    print("-" * 100)
    
    for _, row in rmd_only.iterrows():
        pct_reduction = row['RMD_Reduction'] / row['RMD_No_Conversion'] * 100 if row['RMD_No_Conversion'] > 0 else 0
        print(f"{int(row['Year']):<6} {int(row[f'{household.spouse1.name}_Age']):<7} {int(row[f'{household.spouse2.name}_Age']):<7} "
              f"${row['RMD_No_Conversion']:>12,.0f} ${row['RMD_With_Optimal']:>12,.0f} "
              f"${row['RMD_Reduction']:>10,.0f} {pct_reduction:>10.1f}%")
    
    print("-" * 100)
    total_rmd_reduction = rmd_only['RMD_Reduction'].sum()
    print(f"{'TOTAL':<6} {'':<7} {'':<7} ${rmd_only['RMD_No_Conversion'].sum():>12,.0f} "
          f"${rmd_only['RMD_With_Optimal'].sum():>12,.0f} "
          f"${total_rmd_reduction:>10,.0f}")
    print(f"\n🎯 TOTAL RMD REDUCTION OVER 25 YEARS: ${total_rmd_reduction:,.0f}")
else:
    print("\nNo RMDs in projection period yet (both spouses under age 73).")

# %% [markdown]
# ## 📊 Section 6: Zero RMD Analysis
# **What this shows:** What would it cost to COMPLETELY eliminate RMDs? (Spoiler: You'd need ~$612K more in taxable funds)

# %%
# =============================================================================
# 🎯 ZERO RMD ANALYSIS: What Would It Take to Eliminate RMDs?
# =============================================================================

print("=" * 100)
print("🎯 ZERO RMD ANALYSIS: What Would It Cost to Eliminate RMDs?")
print("=" * 100)

# Key facts
s1_rmd_start_age = 73
s2_rmd_start_age = 73
years_until_s1_rmd = s1_rmd_start_age - SPOUSE1_AGE  # Years until Rajesh hits 73
years_until_s2_rmd = s2_rmd_start_age - SPOUSE2_AGE  # Years until Terri hits 73

print(f"\n📅 TIME UNTIL RMDs BEGIN:")
print(f"   {SPOUSE1_NAME}: {years_until_s1_rmd} years (age {SPOUSE1_AGE} → 73)")
print(f"   {SPOUSE2_NAME}: {years_until_s2_rmd} years (age {SPOUSE2_AGE} → 73)")
print(f"   → You have {min(years_until_s1_rmd, years_until_s2_rmd)} years to convert before first RMD")

# Current pre-tax balances
total_pretax = household.total_pretax
print(f"\n💰 CURRENT PRE-TAX BALANCES:")
print(f"   {SPOUSE1_NAME}: ${household.spouse1.total_pretax:,.0f}")
print(f"   {SPOUSE2_NAME}: ${household.spouse2.total_pretax:,.0f}")
print(f"   TOTAL:   ${total_pretax:,.0f}")

# Project what the IRA will be worth when RMDs start (with growth but accounting for income withdrawals)
# Simplified: assume average IRA growth minus withdrawals
years_to_rmd = min(years_until_s1_rmd, years_until_s2_rmd)

# Estimate how much needs to be in IRA at RMD start to generate zero RMD
# Answer: $0!  To have zero RMD, IRA balance must be $0 at age 73

print(f"\n" + "=" * 100)
print("📊 SCENARIO ANALYSIS: CONVERT EVERYTHING TO ROTH")
print("=" * 100)

# Calculate what it would cost to convert ALL pre-tax to Roth right now
def calculate_full_conversion_cost(amount_to_convert, current_income=0):
    """Calculate tax cost to convert a given amount."""
    std_ded = STANDARD_DEDUCTION_MFJ_2024
    if SPOUSE1_AGE >= 65:
        std_ded += STANDARD_DEDUCTION_65_PLUS_ADDITION
    if SPOUSE2_AGE >= 65:
        std_ded += STANDARD_DEDUCTION_65_PLUS_ADDITION
    
    taxable_income = max(0, current_income + amount_to_convert - std_ded)
    federal_tax = calculate_federal_tax(taxable_income, TAX_BRACKETS_MFJ_2024)
    state_tax = taxable_income * STATE_TAX_RATE
    return federal_tax + state_tax, taxable_income

# Scenario 1: Convert everything in Year 1
full_conv_tax, full_taxable = calculate_full_conversion_cost(total_pretax)
effective_rate = full_conv_tax / total_pretax * 100

print(f"\n🔴 SCENARIO 1: Convert ALL ${total_pretax:,.0f} in ONE YEAR")
print(f"   Taxable income: ${full_taxable:,.0f}")
print(f"   Tax cost:       ${full_conv_tax:,.0f}")
print(f"   Effective rate: {effective_rate:.1f}%")
print(f"   ⚠️  You'd need ${full_conv_tax:,.0f} in taxable to pay taxes!")
print(f"   ⚠️  You only have ${JOINT_TAXABLE_ACCOUNTS:,.0f} - SHORTFALL: ${max(0, full_conv_tax - JOINT_TAXABLE_ACCOUNTS):,.0f}")

# Scenario 2: Spread over available years before RMD
conversion_years_available = years_to_rmd
annual_conversion_needed = total_pretax / conversion_years_available

# But we also need to fund income! Calculate net available for conversion
print(f"\n🟡 SCENARIO 2: Spread conversions over {conversion_years_available} years (before RMDs start)")

# For each year, calculate income need and conversion capacity
total_taxes_scenario2 = 0
remaining_pretax = total_pretax
remaining_taxable = JOINT_TAXABLE_ACCOUNTS

print(f"\n   Year  Age    Income Need   IRA for Income   Available for Conv   Conv Tax   Cumulative Conv")
print("   " + "-" * 95)

cumulative_conv = 0
conversion_schedule = []

for yr in range(conversion_years_available):
    year = 2025 + yr
    s1_age = SPOUSE1_AGE + yr
    s2_age = SPOUSE2_AGE + yr
    
    # Income need (inflation adjusted)
    income_need = ANNUAL_INCOME_NEED * ((1 + INFLATION_RATE) ** yr)
    
    # SS income
    ss1 = household.spouse1.get_ss_income(yr, INFLATION_RATE)
    ss2 = household.spouse2.get_ss_income(yr, INFLATION_RATE)
    ss_income = ss1 + ss2
    
    # How much from IRA for income (after SS)
    ira_for_income = max(0, income_need - ss_income)
    remaining_pretax -= ira_for_income
    
    # What's left of IRA after income withdrawal?
    available_for_conv = max(0, remaining_pretax)
    
    # How much can we convert this year? Limited by taxable account for taxes
    # Estimate tax rate at ~27%
    estimated_tax_rate = 0.27
    max_conv_affordable = remaining_taxable / estimated_tax_rate if remaining_taxable > 0 else 0
    
    # Target: convert equal amounts each year
    target_conv = available_for_conv / max(1, conversion_years_available - yr)
    actual_conv = min(target_conv, max_conv_affordable, available_for_conv)
    
    # Calculate actual tax
    conv_tax, _ = calculate_full_conversion_cost(actual_conv + ira_for_income)
    income_tax, _ = calculate_full_conversion_cost(ira_for_income)
    conv_tax_only = conv_tax - income_tax
    
    remaining_taxable -= conv_tax_only
    remaining_pretax -= actual_conv
    cumulative_conv += actual_conv
    total_taxes_scenario2 += conv_tax_only
    
    conversion_schedule.append({
        'year': year, 'conversion': actual_conv, 'tax': conv_tax_only
    })
    
    print(f"   {year}  {s1_age}/{s2_age}   ${income_need:>10,.0f}   ${ira_for_income:>12,.0f}   ${actual_conv:>16,.0f}   ${conv_tax_only:>9,.0f}   ${cumulative_conv:>14,.0f}")
    
    # Apply growth to remaining balances (simplified)
    remaining_pretax *= (1 + IRA_RETURN)
    remaining_taxable *= (1 + TAXABLE_RETURN)

print("   " + "-" * 95)
print(f"\n   TOTAL CONVERTED: ${cumulative_conv:,.0f}")
print(f"   TOTAL TAXES:     ${total_taxes_scenario2:,.0f}")
print(f"   REMAINING IRA:   ${remaining_pretax:,.0f}")

if remaining_pretax > 10000:
    print(f"\n   ⚠️  You CANNOT eliminate RMDs with current taxable balance!")
    print(f"   ⚠️  Remaining IRA at age 73: ${remaining_pretax:,.0f} → will generate RMDs")
else:
    print(f"\n   ✅ SUCCESS! IRA essentially zeroed out before RMDs!")

# What additional taxable funds would be needed?
print(f"\n" + "=" * 100)
print("💵 WHAT ADDITIONAL FUNDS ARE NEEDED FOR ZERO RMDs?")
print("=" * 100)

# Calculate: to convert $X, need $X * tax_rate in taxable
# But also need to fund income for years before SS/RMD kicks in
# And keep $75K reserve

income_needed_before_ss = 0
for yr in range(years_to_rmd):
    income_yr = ANNUAL_INCOME_NEED * ((1 + INFLATION_RATE) ** yr)
    ss1 = household.spouse1.get_ss_income(yr, INFLATION_RATE)
    ss2 = household.spouse2.get_ss_income(yr, INFLATION_RATE)
    shortfall = max(0, income_yr - ss1 - ss2)
    # This shortfall comes from IRA - it's taxable income
    # But we need to pay tax on it too
    income_needed_before_ss += shortfall

# Total amount to convert = starting IRA - what we withdraw for income
# But IRAs grow! So it's more complex
# Simplified estimate:
amount_to_convert = total_pretax  # Roughly
avg_tax_rate = 0.26  # Blended rate over time
taxes_needed = amount_to_convert * avg_tax_rate

# Income taxes (on IRA withdrawals for living expenses)
income_taxes_estimated = income_needed_before_ss * 0.20  # Lower rate since it's lower amounts

total_taxable_needed = (
    taxes_needed +           # To pay for conversions
    MINIMUM_CASH_RESERVE +   # Keep cash reserve
    income_taxes_estimated   # Pay income taxes
)

additional_needed = max(0, total_taxable_needed - JOINT_TAXABLE_ACCOUNTS)

print(f"\n📊 ROUGH ESTIMATE TO ACHIEVE ZERO RMDs:")
print(f"   Total IRA to convert:           ${total_pretax:,.0f}")
print(f"   Estimated conversion taxes:     ${taxes_needed:,.0f} (at ~{avg_tax_rate*100:.0f}% avg rate)")
print(f"   Income taxes (pre-SS years):    ${income_taxes_estimated:,.0f}")
print(f"   Cash reserve to maintain:       ${MINIMUM_CASH_RESERVE:,.0f}")
print(f"   ────────────────────────────────────────")
print(f"   TOTAL TAXABLE NEEDED:           ${total_taxable_needed:,.0f}")
print(f"   You currently have:             ${JOINT_TAXABLE_ACCOUNTS:,.0f}")
print(f"   ════════════════════════════════════════")
print(f"   ADDITIONAL FUNDS NEEDED:        ${additional_needed:,.0f}")

print(f"\n" + "=" * 100)
print("🤔 IS ZERO RMD WORTH IT?")
print("=" * 100)

# Compare: pay taxes now vs pay taxes later on RMDs
future_rmd_taxes = rmd_only['RMD_No_Conversion'].sum() * 0.26 if len(rmd_only) > 0 else 0

print(f"""
   Option A: CURRENT PLAN (Optimal with constraints)
   ─────────────────────────────────────────────────
   • Convert ${sum(optimal_conversions):,.0f} over 5 years
   • Pay ${optimal_outcome['total_conversion_taxes']:,.0f} in conversion taxes NOW
   • Still have ~${optimal_outcome['final_pretax']:,.0f} in IRA at year 25
   • Future RMDs will be taxed (est. ${optimal_outcome['final_pretax'] * 0.26:,.0f} in taxes over time)
   
   Option B: ZERO RMD (Convert everything)
   ─────────────────────────────────────────────────
   • Convert ALL ${total_pretax:,.0f} before age 73
   • Pay ~${taxes_needed:,.0f} in conversion taxes NOW
   • Additional taxable funds needed: ${additional_needed:,.0f}
   • Zero RMDs forever!
   • All future growth is tax-free in Roth

   💡 KEY INSIGHT:
   • You'd need an additional ~${additional_needed:,.0f} in taxable funds to achieve zero RMDs
   • This could come from: selling assets, inheritance, downsizing home, etc.
   • OR you could accept some RMDs (they're not terrible - just taxable income)
""")

# %% [markdown]
# ## 📊 Section 7: Target $50K/Year Maximum RMD
# **What this shows:** What conversions are needed to cap your annual RMDs at $50,000? (Achievable? Maybe with extra funds)

# %%
# =============================================================================
# TARGET RMD ANALYSIS: What conversions needed to cap RMDs at $50K/year?
# =============================================================================

TARGET_MAX_RMD = 50_000  # Maximum annual RMD we want

print("=" * 100)
print(f"🎯 TARGET RMD ANALYSIS: Cap Annual RMDs at ${TARGET_MAX_RMD:,.0f}/year")
print("=" * 100)

# RMD divisors for ages 73-95
rmd_divisors = {
    73: 26.5, 74: 25.5, 75: 24.6, 76: 23.7, 77: 22.9, 78: 22.0, 79: 21.1, 80: 20.2,
    81: 19.4, 82: 18.5, 83: 17.7, 84: 16.8, 85: 16.0, 86: 15.2, 87: 14.4, 88: 13.7,
    89: 12.9, 90: 12.2, 91: 11.5, 92: 10.8, 93: 10.1, 94: 9.5, 95: 8.9
}

# Calculate what IRA balance produces $50K RMD at each age
print(f"\n📊 IRA BALANCE THAT PRODUCES ${TARGET_MAX_RMD:,.0f} RMD AT EACH AGE:")
print("-" * 60)
print(f"{'Age':<10} {'RMD Divisor':<15} {'Max IRA Balance':<20}")
print("-" * 60)

# Show key ages
key_ages = [73, 75, 80, 85, 90]
for age in key_ages:
    divisor = rmd_divisors[age]
    max_balance = TARGET_MAX_RMD * divisor
    print(f"{age:<10} {divisor:<15.1f} ${max_balance:>15,.0f}")

# At age 73, what balance gives $50K RMD?
max_ira_at_73 = TARGET_MAX_RMD * rmd_divisors[73]
print(f"\n💡 KEY INSIGHT: To keep RMDs at ${TARGET_MAX_RMD:,.0f}/year starting at age 73,")
print(f"   your combined IRA balance should be ≤ ${max_ira_at_73:,.0f} at age 73")

# Current situation
print("\n" + "=" * 100)
print("📈 CURRENT TRAJECTORY vs TARGET")
print("=" * 100)

# Project IRA forward with NO conversions
years_to_73_spouse1 = 73 - SPOUSE1_AGE
years_to_73_spouse2 = 73 - SPOUSE2_AGE

# Calculate IRA balance at age 73 for each spouse (no conversions)
s1_ira_at_73_no_conv = (SPOUSE1_TRADITIONAL_IRA + SPOUSE1_SEP_IRA) * (1 + IRA_RETURN) ** years_to_73_spouse1
s2_ira_at_73_no_conv = (SPOUSE2_TRADITIONAL_IRA + SPOUSE2_SEP_IRA) * (1 + IRA_RETURN) ** years_to_73_spouse2

print(f"\n🔴 WITHOUT CONVERSIONS:")
print(f"   {SPOUSE1_NAME}'s IRA at age 73 (in {years_to_73_spouse1} years): ${s1_ira_at_73_no_conv:,.0f}")
print(f"   {SPOUSE2_NAME}'s IRA at age 73 (in {years_to_73_spouse2} years): ${s2_ira_at_73_no_conv:,.0f}")
print(f"   Combined at first RMD: ${s1_ira_at_73_no_conv + s2_ira_at_73_no_conv:,.0f}")

# What would RMDs be?
s1_rmd_no_conv = s1_ira_at_73_no_conv / rmd_divisors[73]
s2_rmd_no_conv = s2_ira_at_73_no_conv / rmd_divisors[73]
print(f"\n   {SPOUSE1_NAME}'s first RMD: ${s1_rmd_no_conv:,.0f}")
print(f"   {SPOUSE2_NAME}'s first RMD: ${s2_rmd_no_conv:,.0f}")
print(f"   Combined first year RMD: ${s1_rmd_no_conv + s2_rmd_no_conv:,.0f}")

# How much do we need to convert to hit target?
print("\n" + "=" * 100)
print(f"🎯 CONVERSION NEEDED TO CAP RMDs AT ${TARGET_MAX_RMD:,.0f}/YEAR")
print("=" * 100)

# Target: Each spouse's IRA at 73 should produce RMD proportional to their share
# Combined target: $50K RMD means combined IRA of $50K * 26.5 = $1,325,000 at age 73

# Calculate how much needs to be converted
target_combined_ira_at_73 = TARGET_MAX_RMD * rmd_divisors[73]

# We need to figure out the target for each spouse
# Let's assume proportional reduction
s1_current_pretax = SPOUSE1_TRADITIONAL_IRA + SPOUSE1_SEP_IRA
s2_current_pretax = SPOUSE2_TRADITIONAL_IRA + SPOUSE2_SEP_IRA
total_current_pretax = s1_current_pretax + s2_current_pretax

# What each spouse's target should be at age 73 (proportional to current ratio)
s1_ratio = s1_current_pretax / total_current_pretax
s2_ratio = s2_current_pretax / total_current_pretax

s1_target_at_73 = target_combined_ira_at_73 * s1_ratio
s2_target_at_73 = target_combined_ira_at_73 * s2_ratio

print(f"\n📊 TARGET IRA BALANCES AT AGE 73:")
print(f"   Combined target: ${target_combined_ira_at_73:,.0f}")
print(f"   {SPOUSE1_NAME}'s target ({s1_ratio:.1%}): ${s1_target_at_73:,.0f}")
print(f"   {SPOUSE2_NAME}'s target ({s2_ratio:.1%}): ${s2_target_at_73:,.0f}")

# Excess that needs to be converted (accounting for growth during conversion years)
# This is complex - we need to solve for conversions that reduce future balance

# Simplified approach: calculate present value of excess
s1_excess_at_73 = s1_ira_at_73_no_conv - s1_target_at_73
s2_excess_at_73 = s2_ira_at_73_no_conv - s2_target_at_73
total_excess_at_73 = s1_excess_at_73 + s2_excess_at_73

# Present value of excess (what we need to convert today, roughly)
s1_pv_excess = s1_excess_at_73 / (1 + IRA_RETURN) ** years_to_73_spouse1
s2_pv_excess = s2_excess_at_73 / (1 + IRA_RETURN) ** years_to_73_spouse2
total_pv_excess = s1_pv_excess + s2_pv_excess

print(f"\n💰 CONVERSION REQUIREMENT:")
print(f"   Excess {SPOUSE1_NAME} IRA at 73: ${s1_excess_at_73:,.0f} (PV: ${s1_pv_excess:,.0f})")
print(f"   Excess {SPOUSE2_NAME} IRA at 73: ${s2_excess_at_73:,.0f} (PV: ${s2_pv_excess:,.0f})")
print(f"   ────────────────────────────────────────")
print(f"   TOTAL TO CONVERT: ~${total_pv_excess:,.0f}")

# Spread over years available
min_years_to_rmd = min(years_to_73_spouse1, years_to_73_spouse2)
annual_conversion_for_target = total_pv_excess / min_years_to_rmd

print(f"\n📅 CONVERSION SCHEDULE TO HIT ${TARGET_MAX_RMD:,.0f}/YEAR RMD TARGET:")
print(f"   Years until first RMD: {min_years_to_rmd}")
print(f"   Annual conversion needed: ${annual_conversion_for_target:,.0f}/year")

# Estimate taxes
avg_rate = 0.26  # Based on previous analysis
annual_tax = annual_conversion_for_target * avg_rate
total_conversion_tax = total_pv_excess * avg_rate

print(f"\n💸 TAX COST ESTIMATE:")
print(f"   Annual conversion tax: ~${annual_tax:,.0f}")
print(f"   Total conversion tax: ~${total_conversion_tax:,.0f}")

# Compare with current optimal
print("\n" + "=" * 100)
print("📊 COMPARISON: CURRENT OPTIMAL vs $50K RMD TARGET")
print("=" * 100)

# Get optimal conversion amount from previous analysis
optimal_total_conversion = optimal_conversions[0] if optimal_conversions else 0

print(f"\n{'Metric':<40} {'Current Optimal':<20} {'$50K RMD Target':<20}")
print("-" * 80)
print(f"{'Total Conversion':<40} ${optimal_total_conversion:>15,.0f} ${total_pv_excess:>15,.0f}")
print(f"{'Annual Conversion (avg)':<40} ${optimal_total_conversion/5:>15,.0f} ${annual_conversion_for_target:>15,.0f}")
print(f"{'Est. Tax Cost':<40} ${optimal_total_conversion * 0.26:>15,.0f} ${total_conversion_tax:>15,.0f}")
print(f"{'First Year RMD (est)':<40} ${'varies':>14} ${TARGET_MAX_RMD:>15,.0f}")

# Can we afford this with current taxable?
print("\n" + "=" * 100)
print("💵 AFFORDABILITY CHECK")
print("=" * 100)

# Income needs for min_years_to_rmd years before SS kicks in fully
years_before_full_ss = max(0, SPOUSE1_SS_START_AGE - SPOUSE1_AGE)  # Years until first SS
total_income_needs = 0
total_ss_income = 0

print(f"\n📅 YEAR-BY-YEAR CASH FLOW ANALYSIS (until age 73):")
print("-" * 100)
print(f"{'Year':<6} {'Ages':<10} {'Income Need':<15} {'SS Income':<15} {'From IRA/Conv':<15} {'Conv Tax':<12} {'Taxable Used':<15}")
print("-" * 100)

taxable_balance = JOINT_TAXABLE_ACCOUNTS
cumulative_used = 0

for yr in range(min_years_to_rmd):
    year_num = yr + 1
    ages = f"{SPOUSE1_AGE + yr}/{SPOUSE2_AGE + yr}"
    
    # Income need (inflation adjusted)
    income_need = ANNUAL_INCOME_NEED * (1 + INFLATION_RATE) ** yr
    
    # SS income
    ss1 = SPOUSE1_SS_ANNUAL if (SPOUSE1_AGE + yr >= SPOUSE1_SS_START_AGE) else 0
    ss2 = SPOUSE2_SS_ANNUAL if (SPOUSE2_AGE + yr >= SPOUSE2_SS_START_AGE) else 0
    ss_total = ss1 + ss2
    
    # Shortfall from IRA
    from_ira = max(0, income_need - ss_total)
    
    # Conversion for this year
    conversion_this_year = annual_conversion_for_target
    
    # Tax on conversion + income
    total_taxable_income = from_ira + conversion_this_year
    conv_tax = total_taxable_income * avg_rate
    
    # Taxable account pays: income shortfall taxes + conversion taxes
    taxable_used = conv_tax
    cumulative_used += taxable_used
    taxable_balance = taxable_balance * (1 + TAXABLE_RETURN) - taxable_used
    
    if yr < 5 or yr >= min_years_to_rmd - 2:  # Show first 5 and last 2 years
        print(f"{year_num:<6} {ages:<10} ${income_need:>12,.0f} ${ss_total:>12,.0f} ${from_ira:>12,.0f} ${conv_tax:>9,.0f} ${cumulative_used:>12,.0f}")
    elif yr == 5:
        print(f"{'...':<6} {'...':<10} {'...':<15} {'...':<15} {'...':<15} {'...':<12} {'...':<15}")

print("-" * 100)
print(f"{'TOTALS':<6} {'':<10} ${ANNUAL_INCOME_NEED * sum((1+INFLATION_RATE)**i for i in range(min_years_to_rmd)):>12,.0f} {'':<15} {'':<15} ${total_conversion_tax:>9,.0f}")

print(f"\n📊 TAXABLE ACCOUNT STATUS:")
print(f"   Starting balance: ${JOINT_TAXABLE_ACCOUNTS:,.0f}")
print(f"   Total conversion taxes: ${total_conversion_tax:,.0f}")
print(f"   Ending taxable (est): ${taxable_balance:,.0f}")
print(f"   Required cash reserve: ${MINIMUM_CASH_RESERVE:,.0f}")

if taxable_balance >= MINIMUM_CASH_RESERVE:
    print(f"\n   ✅ AFFORDABLE! You can achieve ${TARGET_MAX_RMD:,.0f}/year max RMDs")
    print(f"   Surplus above reserve: ${taxable_balance - MINIMUM_CASH_RESERVE:,.0f}")
else:
    shortfall = MINIMUM_CASH_RESERVE - taxable_balance
    print(f"\n   ⚠️  SHORTFALL: You need an additional ${shortfall:,.0f} to maintain reserve")
    print(f"   Consider: Higher RMD target, or find additional funds")

# Final summary
print("\n" + "=" * 100)
print("🎯 SUMMARY: $50K/YEAR RMD TARGET STRATEGY")
print("=" * 100)
print(f"""
   TO CAP YOUR RMDs AT ${TARGET_MAX_RMD:,.0f}/YEAR:
   
   1. Convert ~${total_pv_excess:,.0f} total before age 73
   2. That's ~${annual_conversion_for_target:,.0f}/year for {min_years_to_rmd} years
   3. Pay ~${total_conversion_tax:,.0f} in conversion taxes
   4. Your IRA at 73 will be ~${target_combined_ira_at_73:,.0f}
   5. First RMD at 73: ~${TARGET_MAX_RMD:,.0f}
   
   TRADE-OFF:
   • Current optimal converts ${optimal_total_conversion:,.0f} → higher RMDs but lower taxes now
   • $50K target converts ${total_pv_excess:,.0f} → lower RMDs but higher taxes now
   • Additional tax cost: ${total_conversion_tax - optimal_total_conversion * 0.26:,.0f}
""")

# %% [markdown]
# # ⭐⭐⭐ 📖 YOUR RETIREMENT STORY ⭐⭐⭐
# ## Rajesh & Terri's Financial Journey - THE COMPLETE SUMMARY
#
# **👉 THIS IS THE MAIN OUTPUT - Everything else above is supporting analysis**
#
# This cell consolidates ALL the analysis into one easy-to-read narrative covering:
# - Where you stand today
# - Your three options (Do Nothing, Smart Convert, Aggressive)
# - Should you use IRA money to pay taxes? (Spoiler: NO)
# - Your recommended strategy
# - What-if scenarios

# %%
# =============================================================================
# 📖 YOUR RETIREMENT STORY: Consolidated Summary & Decision Guide
# =============================================================================
# This cell brings together ALL the analysis into one easy-to-read narrative

import textwrap

def print_story():
    """Generate Rajesh & Terri's personalized retirement story"""
    
    # Current situation
    total_pretax = SPOUSE1_TRADITIONAL_IRA + SPOUSE1_SEP_IRA + SPOUSE2_TRADITIONAL_IRA + SPOUSE2_SEP_IRA
    total_roth = SPOUSE1_ROTH_IRA + SPOUSE2_ROTH_IRA
    total_taxable = JOINT_TAXABLE_ACCOUNTS
    total_wealth = total_pretax + total_roth + total_taxable
    
    # Key ages and milestones
    terri_ss_start = SPOUSE2_SS_START_AGE
    rajesh_ss_start = SPOUSE1_SS_START_AGE
    first_rmd_age = 73
    years_to_terri_rmd = first_rmd_age - SPOUSE2_AGE
    years_to_rajesh_rmd = first_rmd_age - SPOUSE1_AGE
    
    print("=" * 100)
    print("📖 THE CHAWLA FAMILY RETIREMENT STORY")
    print("=" * 100)
    
    print(f"""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                              CHAPTER 1: WHERE YOU STAND TODAY                                   │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

Meet {SPOUSE1_NAME} (age {SPOUSE1_AGE}) and {SPOUSE2_NAME} (age {SPOUSE2_AGE}). After decades of hard work and 
diligent saving, you've built a substantial nest egg:

    💰 YOUR WEALTH TODAY
    ─────────────────────────────────────────────
    Pre-Tax IRAs (Traditional + SEP):  ${total_pretax:>12,.0f}
    Roth IRAs:                         ${total_roth:>12,.0f}
    Taxable Brokerage Account:         ${total_taxable:>12,.0f}
    ─────────────────────────────────────────────
    TOTAL WEALTH:                      ${total_wealth:>12,.0f}

    📊 THE CHALLENGE: {total_pretax/total_wealth:.0%} of your wealth is in pre-tax accounts
    
    This means Uncle Sam is your silent partner in {total_pretax/total_wealth:.0%} of your savings.
    Every dollar you withdraw will be taxed as ordinary income.

┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                          CHAPTER 2: YOUR INCOME NEEDS & TIMELINE                                │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

You need ${MONTHLY_INCOME_NEED:,}/month (${ANNUAL_INCOME_NEED:,}/year) to maintain your lifestyle, 
plus you want ${MINIMUM_CASH_RESERVE:,} cash reserve for emergencies.

    📅 KEY MILESTONES AHEAD
    ─────────────────────────────────────────────────────────────────────────────
    • Year 1-4:   No Social Security - all income from savings
    • Year 5:     {SPOUSE2_NAME} starts Social Security at age {terri_ss_start} (${SPOUSE2_SS_ANNUAL:,}/year)  
    • Year 8:     {SPOUSE1_NAME} starts Social Security at age {rajesh_ss_start} (${SPOUSE1_SS_ANNUAL:,}/year)
    • Year 12:    {SPOUSE2_NAME} turns 73 - RMDs BEGIN for her IRAs
    • Year 13:    {SPOUSE1_NAME} turns 73 - RMDs BEGIN for his IRAs
    ─────────────────────────────────────────────────────────────────────────────

    🚨 THE RMD PROBLEM:
    Without action, your combined IRA will grow to ~$6M by age 73.
    Your FIRST required minimum distribution would be ~$226,000!
    That's forced taxable income whether you need it or not.
""")

    print("""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                         CHAPTER 3: THE THREE PATHS BEFORE YOU                                   │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘
""")

    # =========================================================================
    # PATH A: DO NOTHING
    # =========================================================================
    
    # Calculate do-nothing scenario
    ira_at_73_no_conv = total_pretax * (1 + IRA_RETURN) ** min(years_to_terri_rmd, years_to_rajesh_rmd)
    first_rmd_no_conv = ira_at_73_no_conv / 26.5  # divisor at age 73
    
    # Estimate lifetime RMD taxes (simplified)
    avg_rmd_tax_rate = 0.28  # Higher bracket due to large RMDs
    lifetime_rmd_taxes_no_conv = first_rmd_no_conv * 20 * avg_rmd_tax_rate  # ~20 years of RMDs
    
    print(f"""
    ════════════════════════════════════════════════════════════════════════════
    PATH A: "DO NOTHING" - Let the IRAs Grow
    ════════════════════════════════════════════════════════════════════════════
    
    What happens if you make NO Roth conversions?
    
    ✓ Simple - no extra tax planning needed
    ✓ Maximum IRA growth (no money taken for taxes)
    ✗ HUGE RMDs starting at age 73
    ✗ Pushed into highest tax brackets in retirement
    ✗ Less flexibility - IRS dictates your withdrawals
    
    PROJECTED OUTCOME:
    • IRA balance at age 73:     ${ira_at_73_no_conv:>12,.0f}
    • First year RMD:            ${first_rmd_no_conv:>12,.0f}
    • Est. lifetime RMD taxes:   ${lifetime_rmd_taxes_no_conv:>12,.0f}
    
    💭 "We'll deal with taxes when we have to. Why pay now?"
""")

    # =========================================================================
    # PATH B: OPTIMAL CONVERSIONS (pay taxes from taxable)
    # =========================================================================
    
    # Use results from optimization
    optimal_conv_total = float(optimal_conversions[0]) if optimal_conversions else 250000
    optimal_taxes = optimal_conv_total * 0.26
    reduced_ira_at_73 = (total_pretax - optimal_conv_total) * (1 + IRA_RETURN) ** 12
    reduced_first_rmd = reduced_ira_at_73 / 26.5
    
    print(f"""
    ════════════════════════════════════════════════════════════════════════════
    PATH B: "SMART CONVERSIONS" - Optimal Strategy (Pay Taxes from Taxable)
    ════════════════════════════════════════════════════════════════════════════
    
    What if you convert strategically, paying taxes from your taxable account?
    
    ✓ Reduces future RMDs significantly
    ✓ Moves money to tax-FREE Roth growth
    ✓ Maintains your taxable account for flexibility
    ✓ Stays within manageable tax brackets
    ✗ Uses up some of your taxable account for taxes
    
    PROJECTED OUTCOME:
    • Total Roth conversions:    ${optimal_conv_total:>12,.0f} over 4-5 years
    • Conversion taxes paid:     ${optimal_taxes:>12,.0f}
    • IRA balance at age 73:     ${reduced_ira_at_73:>12,.0f}
    • First year RMD:            ${reduced_first_rmd:>12,.0f}
    • RMD REDUCTION:             ${first_rmd_no_conv - reduced_first_rmd:>12,.0f}/year!
    
    💭 "Pay a little tax now, save a LOT of tax later."
""")

    # =========================================================================
    # PATH C: AGGRESSIVE CONVERSIONS (fund taxes from IRA)
    # =========================================================================
    
    print("""
    ════════════════════════════════════════════════════════════════════════════
    PATH C: "ALL IN" - Use IRA Money to Pay Conversion Taxes
    ════════════════════════════════════════════════════════════════════════════
    
    What if you convert aggressively, using IRA withdrawals to pay the taxes?
    (This is called "grossing up" - you withdraw extra to cover the tax bill)
    
    ⚠️ ANALYSIS: Is it worth using IRA money to pay conversion taxes?
""")

    # Calculate gross-up scenario
    # If you want to convert $100K net to Roth, and tax rate is 26%, 
    # you need to withdraw $100K / (1 - 0.26) = $135K
    # $135K withdrawal = $100K to Roth + $35K for taxes
    
    target_net_conversion = 500000  # How much we want to END UP in Roth
    tax_rate = 0.26
    gross_withdrawal_needed = target_net_conversion / (1 - tax_rate)
    taxes_from_ira = gross_withdrawal_needed - target_net_conversion
    
    # Alternative: pay from taxable
    taxes_from_taxable = target_net_conversion * tax_rate
    
    # Compare future value
    years_to_grow = 20  # How long will this grow?
    
    # If you use IRA to pay taxes, you lose IRA growth
    fv_lost_from_ira = taxes_from_ira * (1 + IRA_RETURN) ** years_to_grow
    
    # If you use taxable to pay taxes, you lose taxable growth
    fv_lost_from_taxable = taxes_from_taxable * (1 + TAXABLE_RETURN) ** years_to_grow
    
    # BUT the key insight: taxable growth is partly taxed, Roth is not
    after_tax_fv_lost_taxable = fv_lost_from_taxable * 0.85  # ~15% cap gains
    
    print(f"""
    📊 COMPARING: Pay Taxes from IRA vs Taxable
    ─────────────────────────────────────────────────────────────────────────────
    Goal: Move ${target_net_conversion:,.0f} into Roth IRA
    
    OPTION 1: Pay taxes from TAXABLE account
    • Convert ${target_net_conversion:,.0f} from IRA to Roth
    • Pay ${taxes_from_taxable:,.0f} taxes from taxable account
    • Future value of lost taxable (20 yrs): ${fv_lost_from_taxable:,.0f}
      (After cap gains tax: ${after_tax_fv_lost_taxable:,.0f})
    
    OPTION 2: Pay taxes from IRA ("gross up")
    • Withdraw ${gross_withdrawal_needed:,.0f} from IRA
    • ${target_net_conversion:,.0f} goes to Roth, ${taxes_from_ira:,.0f} goes to IRS
    • Future value of lost IRA (20 yrs): ${fv_lost_from_ira:,.0f}
      (Would have been fully taxable as RMD anyway)
    
    🧮 THE MATH:
    • Lost opportunity cost (IRA): ${fv_lost_from_ira:,.0f}
    • Lost opportunity cost (Taxable, after-tax): ${after_tax_fv_lost_taxable:,.0f}
    • DIFFERENCE: ${abs(fv_lost_from_ira - after_tax_fv_lost_taxable):,.0f}
""")

    if fv_lost_from_ira > after_tax_fv_lost_taxable:
        print(f"""
    💡 VERDICT: PAY TAXES FROM TAXABLE ACCOUNT
    
    It's BETTER to use your taxable account to pay conversion taxes because:
    1. Taxable money grows slower (6.8% vs 6.4% IRA vs 7.2% Roth)
    2. Taxable gains are taxed anyway (capital gains)
    3. You preserve more in tax-advantaged accounts
    4. Every dollar in Roth grows 100% tax-free forever
    
    Using IRA money to pay taxes costs you ${fv_lost_from_ira - after_tax_fv_lost_taxable:,.0f} more
    in lost future wealth over 20 years.
""")
    else:
        print(f"""
    💡 VERDICT: Using IRA money isn't terrible, but taxable is still better.
""")

    # =========================================================================
    # THE BIG PICTURE COMPARISON
    # =========================================================================
    
    print("""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                         CHAPTER 4: THE BOTTOM LINE - YOUR CHOICES                               │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘
""")

    # Calculate 25-year projections for each path
    
    # PATH A: No conversions
    path_a_ira_25 = total_pretax * (1 + IRA_RETURN) ** 25
    path_a_taxable_25 = total_taxable * (1 + TAXABLE_RETURN) ** 25
    path_a_roth_25 = 0
    path_a_total_25 = path_a_ira_25 * 0.75 + path_a_taxable_25 * 0.92 + path_a_roth_25  # After-tax
    
    # PATH B: Optimal conversions
    path_b_conv = optimal_conv_total
    path_b_taxes = path_b_conv * 0.26
    path_b_ira_start = total_pretax - path_b_conv
    path_b_taxable_start = total_taxable - path_b_taxes
    path_b_roth_start = path_b_conv
    path_b_ira_25 = path_b_ira_start * (1 + IRA_RETURN) ** 25
    path_b_taxable_25 = path_b_taxable_start * (1 + TAXABLE_RETURN) ** 25
    path_b_roth_25 = path_b_roth_start * (1 + ROTH_RETURN) ** 25
    path_b_total_25 = path_b_ira_25 * 0.75 + path_b_taxable_25 * 0.92 + path_b_roth_25
    
    # PATH C: More aggressive (cap RMDs at $100K)
    path_c_conv = 1500000  # Convert more
    path_c_taxes = path_c_conv * 0.26
    path_c_ira_start = total_pretax - path_c_conv
    path_c_taxable_start = max(0, total_taxable - path_c_taxes)
    path_c_roth_start = path_c_conv
    # If taxable goes negative, need to fund from IRA
    if total_taxable < path_c_taxes:
        extra_from_ira = (path_c_taxes - total_taxable) / (1 - 0.26)
        path_c_ira_start -= extra_from_ira
        path_c_taxable_start = 75000  # minimum reserve
    path_c_ira_25 = max(0, path_c_ira_start) * (1 + IRA_RETURN) ** 25
    path_c_taxable_25 = path_c_taxable_start * (1 + TAXABLE_RETURN) ** 25
    path_c_roth_25 = path_c_roth_start * (1 + ROTH_RETURN) ** 25
    path_c_total_25 = path_c_ira_25 * 0.75 + path_c_taxable_25 * 0.92 + path_c_roth_25

    print(f"""
    ╔═════════════════════════════════════════════════════════════════════════════════════════════╗
    ║                        COMPARISON: 25 YEARS FROM NOW (Ages 85/86)                           ║
    ╠═════════════════════════════════════════════════════════════════════════════════════════════╣
    ║                           │  PATH A:         │  PATH B:           │  PATH C:               ║
    ║          METRIC           │  Do Nothing      │  Smart Convert     │  Aggressive            ║
    ╠═══════════════════════════╪══════════════════╪════════════════════╪════════════════════════╣
    ║ Conversions               │ ${0:>13,.0f}  │ ${path_b_conv:>15,.0f}  │ ${path_c_conv:>18,.0f}  ║
    ║ Taxes Paid Now            │ ${0:>13,.0f}  │ ${path_b_taxes:>15,.0f}  │ ${path_c_taxes:>18,.0f}  ║
    ╠═══════════════════════════╪══════════════════╪════════════════════╪════════════════════════╣
    ║ IRA at Year 25            │ ${path_a_ira_25:>13,.0f}  │ ${path_b_ira_25:>15,.0f}  │ ${path_c_ira_25:>18,.0f}  ║
    ║ Roth at Year 25           │ ${path_a_roth_25:>13,.0f}  │ ${path_b_roth_25:>15,.0f}  │ ${path_c_roth_25:>18,.0f}  ║
    ║ Taxable at Year 25        │ ${path_a_taxable_25:>13,.0f}  │ ${path_b_taxable_25:>15,.0f}  │ ${path_c_taxable_25:>18,.0f}  ║
    ╠═══════════════════════════╪══════════════════╪════════════════════╪════════════════════════╣
    ║ AFTER-TAX WEALTH          │ ${path_a_total_25:>13,.0f}  │ ${path_b_total_25:>15,.0f}  │ ${path_c_total_25:>18,.0f}  ║
    ║ vs Do Nothing             │ ${0:>13,.0f}  │ ${path_b_total_25-path_a_total_25:>+15,.0f}  │ ${path_c_total_25-path_a_total_25:>+18,.0f}  ║
    ╚═══════════════════════════╧══════════════════╧════════════════════╧════════════════════════╝
    
    🎯 First-Year RMD at Age 73:
    ─────────────────────────────────────────────────────────────────────────────
       Path A: ~${first_rmd_no_conv:>10,.0f} (OUCH - huge tax bill!)
       Path B: ~${reduced_first_rmd:>10,.0f} (Manageable)
       Path C: ~${path_c_ira_start * (1+IRA_RETURN)**12 / 26.5:>10,.0f} (Even better)
""")

    # =========================================================================
    # CHAPTER 5: RECOMMENDATION
    # =========================================================================
    
    print("""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                              CHAPTER 5: YOUR RECOMMENDED STRATEGY                               │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘
""")

    print(f"""
    Based on your situation - ${total_taxable:,} in taxable, needing ${ANNUAL_INCOME_NEED:,}/year
    income, and wanting to keep ${MINIMUM_CASH_RESERVE:,} cash reserve:

    ═══════════════════════════════════════════════════════════════════════════
    ✅ RECOMMENDED: PATH B - SMART CONVERSIONS
    ═══════════════════════════════════════════════════════════════════════════

    📋 YOUR 5-YEAR ACTION PLAN:
    
    YEAR 1 (2025): Convert ~${optimal_conv_total/4:,.0f}
    • You're 60/61, no Social Security yet
    • Taxable income: Conversion + living expenses
    • Pay taxes from taxable account
    • Estimated tax: ~${optimal_conv_total/4 * 0.26:,.0f}
    
    YEAR 2-4: Continue conversions of ~${optimal_conv_total/4:,.0f}/year
    • Build up your Roth balance
    • By Year 5, Terri starts SS (${SPOUSE2_SS_ANNUAL:,}/year helps)
    
    YEAR 5+: Evaluate and adjust
    • With SS income, you may convert less
    • Or continue converting to further reduce RMDs
    
    ═══════════════════════════════════════════════════════════════════════════
    
    💰 WHAT YOU'LL ACHIEVE:
    
    • Convert ${optimal_conv_total:,.0f} to Roth over 4-5 years
    • Pay ${optimal_taxes:,.0f} in conversion taxes
    • Reduce first-year RMD by ${first_rmd_no_conv - reduced_first_rmd:,.0f}
    • Gain ${path_b_total_25 - path_a_total_25:,.0f} in after-tax wealth by Year 25
    • More flexibility and control over your taxes
    
    ═══════════════════════════════════════════════════════════════════════════

    🚫 WHAT TO AVOID:
    
    • DON'T use IRA money to pay conversion taxes (costs you more)
    • DON'T try to eliminate RMDs entirely (not affordable with current assets)
    • DON'T convert so much you deplete your taxable reserve
    • DON'T ignore this - doing nothing costs ~${path_a_total_25 - path_b_total_25:,.0f} over 25 years!
""")

    # =========================================================================
    # CHAPTER 6: WHAT IF? SCENARIOS
    # =========================================================================
    
    print("""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                              CHAPTER 6: WHAT IF? SCENARIOS                                      │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

    What if you want to be MORE aggressive about reducing RMDs?
    
    To achieve different RMD levels, you'd need:
""")

    rmd_targets = [50000, 75000, 100000, 125000]
    for target_rmd in rmd_targets:
        target_ira_at_73 = target_rmd * 26.5
        current_ira_at_73_projected = total_pretax * (1 + IRA_RETURN) ** 12
        excess_to_convert = current_ira_at_73_projected - target_ira_at_73
        pv_excess = excess_to_convert / (1 + IRA_RETURN) ** 12
        taxes_needed = pv_excess * 0.26
        affordable = "✅ Possible" if taxes_needed < total_taxable - MINIMUM_CASH_RESERVE else "❌ Need more funds"
        print(f"    ${target_rmd:>7,}/year RMD → Convert ${pv_excess:>12,.0f} | Tax: ${taxes_needed:>10,.0f} | {affordable}")

    print(f"""
    
    ─────────────────────────────────────────────────────────────────────────────
    
    What if you receive additional funds? (inheritance, home sale, etc.)
    
    With an extra $500,000 in taxable, you could:
    • Convert an additional ~$1.9M to Roth
    • Bring RMDs down to ~$75,000/year
    • Save significantly more in lifetime taxes
    
    ═══════════════════════════════════════════════════════════════════════════
""")

    print("""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                                     THE END... FOR NOW                                          │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

    🎬 Remember: This is a PROJECTION based on assumptions:
       • Investment returns: 6.4-7.2% depending on account
       • Inflation: 2.5%
       • Tax brackets: 2024 rates (may change)
       • Your income needs: $132,000/year increasing with inflation
    
    📅 NEXT STEPS:
       1. Review this plan with a financial advisor
       2. Consider tax implications in your state
       3. Start your first conversion before year-end if desired
       4. Re-evaluate annually as circumstances change
    
    💝 The goal isn't just wealth - it's FREEDOM and SECURITY for you and Terri
       in your retirement years. Smart tax planning now means more choices later.

═══════════════════════════════════════════════════════════════════════════════════════════════════
""")

# Run the story
print_story()

# %% [markdown]
# # 🤔 SHOULD YOU CONTINUE CONVERSIONS BEYOND 5 YEARS?
#
# This analysis helps you decide when to STOP converting.

# %%
# =============================================================================
# 🤔 SHOULD YOU CONTINUE CONVERSIONS BEYOND 5 YEARS?
# =============================================================================
# This analysis helps you understand:
# 1. The "marginal benefit" of each additional year of conversions
# 2. When conversions stop making sense
# 3. Key decision factors for your situation

print("=" * 100)
print("🤔 EXTENDED CONVERSION ANALYSIS: Should You Go Beyond 5 Years?")
print("=" * 100)

# Key decision factors
print("""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                           KEY FACTORS FOR CONTINUING CONVERSIONS                                │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

The decision to continue converting depends on these factors:

  ✅ REASONS TO CONTINUE CONVERTING:
     • You have taxable funds left to pay conversion taxes
     • Your current tax bracket is LOWER than your expected RMD tax bracket
     • You still have 12 years before RMDs start (time = value)
     • You want to reduce RMDs further
     • You want more tax-free income in later retirement

  🛑 REASONS TO STOP CONVERTING:
     • Taxable account is depleted (below your $75K reserve)
     • Social Security pushes you into higher brackets
     • Conversion tax rate ≥ expected RMD tax rate
     • You've reduced RMDs to an acceptable level
     • You need flexibility (keeping money accessible in taxable)
""")

# Calculate year-by-year analysis
print("\n" + "=" * 100)
print("📊 YEAR-BY-YEAR CONVERSION ANALYSIS (Years 1-12 before RMDs)")
print("=" * 100)

# Your situation
total_pretax = SPOUSE1_TRADITIONAL_IRA + SPOUSE1_SEP_IRA + SPOUSE2_TRADITIONAL_IRA + SPOUSE2_SEP_IRA
taxable_start = JOINT_TAXABLE_ACCOUNTS
years_to_rmd = 12  # Terri hits 73 first

print(f"\n📍 YOUR STARTING POINT:")
print(f"   Pre-tax IRAs:    ${total_pretax:>12,.0f}")
print(f"   Taxable account: ${taxable_start:>12,.0f}")
print(f"   Years to RMDs:   {years_to_rmd}")
print(f"   Cash reserve:    ${MINIMUM_CASH_RESERVE:>12,.0f}")
print(f"   Annual income need: ${ANNUAL_INCOME_NEED:>10,.0f}")

# Simulate each year
print(f"\n{'Year':<6} {'Your Age':<10} {'SS Income':<12} {'Tax Bracket':<12} {'Taxable Left':<14} {'Can Convert?':<12} {'Recommendation'}")
print("-" * 100)

taxable_balance = taxable_start
ira_balance = total_pretax
annual_conversion = 150000  # Reasonable annual conversion

for yr in range(1, years_to_rmd + 1):
    ages = f"{SPOUSE1_AGE + yr - 1}/{SPOUSE2_AGE + yr - 1}"
    
    # Social Security income for this year
    ss1 = SPOUSE1_SS_ANNUAL if (SPOUSE1_AGE + yr - 1 >= SPOUSE1_SS_START_AGE) else 0
    ss2 = SPOUSE2_SS_ANNUAL if (SPOUSE2_AGE + yr - 1 >= SPOUSE2_SS_START_AGE) else 0
    ss_total = ss1 + ss2
    
    # Income need from other sources
    income_need = ANNUAL_INCOME_NEED * (1 + INFLATION_RATE) ** (yr - 1)
    income_from_ira = max(0, income_need - ss_total)
    
    # Taxable income = income from IRA + any conversion
    base_taxable_income = income_from_ira
    
    # What bracket are you in without conversions?
    if base_taxable_income < 23200:
        base_bracket = "10%"
        base_rate = 0.10
    elif base_taxable_income < 94300:
        base_bracket = "12%"
        base_rate = 0.12
    elif base_taxable_income < 201050:
        base_bracket = "22%"
        base_rate = 0.22
    elif base_taxable_income < 383900:
        base_bracket = "24%"
        base_rate = 0.24
    else:
        base_bracket = "32%+"
        base_rate = 0.32
    
    # How much can you convert while staying in 24% or lower?
    room_to_24 = max(0, 383900 - base_taxable_income)
    
    # Taxes if you convert
    if room_to_24 > 0:
        conv_amount = min(annual_conversion, room_to_24)
        conv_tax = conv_amount * 0.24  # Marginal rate
    else:
        conv_amount = 0
        conv_tax = 0
    
    # Update taxable balance
    # Taxable grows, minus taxes paid, minus income needs not covered by SS
    taxable_balance = taxable_balance * (1 + TAXABLE_RETURN)
    taxable_balance -= conv_tax
    taxable_balance -= max(0, income_from_ira * 0.22)  # Income taxes
    
    # Can you afford to convert?
    can_convert = taxable_balance > MINIMUM_CASH_RESERVE + 50000  # $50K buffer
    
    # Recommendation
    if not can_convert:
        recommendation = "❌ STOP - Low taxable"
    elif ss_total > 80000:
        recommendation = "⚠️  Reduce - SS filling brackets"
    elif base_rate >= 0.24:
        recommendation = "⚠️  Reduce amount"
    else:
        recommendation = "✅ Continue"
    
    print(f"{yr:<6} {ages:<10} ${ss_total:>9,.0f} {base_bracket:<12} ${taxable_balance:>11,.0f} {'Yes' if can_convert else 'No':<12} {recommendation}")
    
    # Update IRA (grows, minus income drawn, minus conversions)
    ira_balance = ira_balance * (1 + IRA_RETURN) - income_from_ira - (conv_amount if can_convert else 0)

# Key insights
print("\n" + "=" * 100)
print("💡 KEY INSIGHTS FOR YOUR SITUATION")
print("=" * 100)

print(f"""
┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│                              YOUR CONVERSION WINDOW ANALYSIS                                    │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

📅 YEARS 1-4 (Ages 60-64): THE GOLDEN WINDOW
   • No Social Security yet
   • Low base income = low tax brackets
   • Maximum room for conversions
   • ✅ CONVERT AGGRESSIVELY

📅 YEAR 5 (Age 65): TERRI'S SS STARTS
   • ${SPOUSE2_SS_ANNUAL:,}/year added to taxable income
   • Tax bracket moves up
   • Less room for conversions
   • ⚠️  REDUCE CONVERSION AMOUNT

📅 YEAR 8 (Age 67): RAJESH'S SS STARTS  
   • Combined SS: ${SPOUSE1_SS_ANNUAL + SPOUSE2_SS_ANNUAL:,}/year
   • Base income now ~${SPOUSE1_SS_ANNUAL + SPOUSE2_SS_ANNUAL:,} before any IRA draws
   • Much less bracket room
   • ⚠️  CONVERT LESS OR STOP

📅 YEARS 9-12: EVALUATE ANNUALLY
   • SS + income needs may fill 22-24% brackets
   • Conversions may push you into 32%+
   • Only convert if: taxable is strong AND you're still in 22-24%
""")

# The math of continuing
print("\n" + "=" * 100)
print("🧮 THE MATH: When Does Converting STOP Making Sense?")
print("=" * 100)

print("""
RULE OF THUMB: Stop converting when:

   Conversion Tax Rate  ≥  Expected RMD Tax Rate

YOUR NUMBERS:
""")

# Calculate expected RMD tax rate
projected_ira_at_73 = (total_pretax - 500000) * (1 + IRA_RETURN) ** 12  # After some conversions
first_rmd = projected_ira_at_73 / 26.5
combined_ss_at_73 = SPOUSE1_SS_ANNUAL + SPOUSE2_SS_ANNUAL

total_income_at_73 = first_rmd + combined_ss_at_73
if total_income_at_73 > 383900:
    rmd_bracket = "32%"
    rmd_rate = 0.32
elif total_income_at_73 > 201050:
    rmd_bracket = "24%"
    rmd_rate = 0.24
elif total_income_at_73 > 94300:
    rmd_bracket = "22%"
    rmd_rate = 0.22
else:
    rmd_bracket = "12%"
    rmd_rate = 0.12

print(f"   • Your SS at 73: ${combined_ss_at_73:,.0f}")
print(f"   • Projected first RMD (after conversions): ${first_rmd:,.0f}")
print(f"   • Total income at 73: ${total_income_at_73:,.0f}")
print(f"   • Expected RMD tax bracket: {rmd_bracket}")
print(f"")
print(f"   ➡️  You should convert as long as your conversion bracket is ≤ {rmd_bracket}")
print(f"   ➡️  Once SS fills lower brackets (Years 5+), be more selective")

# Final recommendation
print("\n" + "=" * 100)
print("✅ BOTTOM LINE RECOMMENDATION")
print("=" * 100)

print(f"""
FOR RAJESH & TERRI:

   YEARS 1-4 (2025-2028):  Convert ~$100-150K/year
   ─────────────────────────────────────────────────────────────────────
   • Low tax brackets (12-24%)
   • No SS income competing for bracket space
   • Taxable account can cover taxes
   • ✅ THIS IS YOUR PRIME CONVERSION WINDOW

   YEAR 5 (2029):  Reduce to ~$50-75K/year
   ─────────────────────────────────────────────────────────────────────
   • Terri's SS starts (${SPOUSE2_SS_ANNUAL:,})
   • Less bracket room available
   • Still worthwhile but smaller amounts

   YEARS 6-7 (2030-2031):  Convert ~$25-50K/year
   ─────────────────────────────────────────────────────────────────────
   • More SS income filling brackets
   • Convert only what fits in 22-24% bracket
   • Check taxable balance annually

   YEAR 8+ (2032+):  Re-evaluate Annually
   ─────────────────────────────────────────────────────────────────────
   • Both SS incomes active (~${SPOUSE1_SS_ANNUAL + SPOUSE2_SS_ANNUAL:,}/year)
   • May have little room for conversions
   • Only convert if: still in 22-24% bracket AND taxable is healthy

   🛑 STOP CONVERTING WHEN:
   ─────────────────────────────────────────────────────────────────────
   • Taxable balance < $125,000 ($75K reserve + $50K buffer)
   • Conversion would push you into 32% bracket
   • RMDs are already at acceptable level (<$100K/year)

═══════════════════════════════════════════════════════════════════════════════════════════════════
""")

# Quick reference table
print("\n📋 QUICK REFERENCE: Conversion Decision Checklist")
print("=" * 100)
print("""
Each year, ask yourself:

   □ Is my taxable balance above $125K?              Yes → Continue  |  No → Stop
   □ Will conversion keep me in 24% bracket or less? Yes → Continue  |  No → Reduce
   □ Is SS income taking up my bracket room?         No → Full amt   |  Yes → Reduce
   □ Am I already in a higher bracket than RMD?      No → Continue   |  Yes → Stop
   □ Have I reduced RMDs to acceptable level?        No → Continue   |  Yes → Optional

If most answers point to "Continue" → Convert that year
If most answers point to "Stop/Reduce" → Skip or reduce conversion
""")

# %%
# =============================================================================
# VISUALIZATION: INCOME SOURCES OVER TIME
# =============================================================================

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Income Sources Stacked Area
ax1 = axes[0, 0]
years = optimal_yearly_df['calendar_year']
ax1.fill_between(years, 0, optimal_yearly_df['income_from_ss'], 
                 alpha=0.8, label='Social Security', color='steelblue')
ax1.fill_between(years, optimal_yearly_df['income_from_ss'], 
                 optimal_yearly_df['income_from_ss'] + optimal_yearly_df['income_from_rmd'],
                 alpha=0.8, label='RMDs', color='coral')
ax1.fill_between(years, 
                 optimal_yearly_df['income_from_ss'] + optimal_yearly_df['income_from_rmd'],
                 optimal_yearly_df['income_from_ss'] + optimal_yearly_df['income_from_rmd'] + optimal_yearly_df['additional_ira_withdrawal'],
                 alpha=0.8, label='IRA Withdrawals', color='gold')
ax1.fill_between(years, 
                 optimal_yearly_df['income_from_ss'] + optimal_yearly_df['income_from_rmd'] + optimal_yearly_df['additional_ira_withdrawal'],
                 optimal_yearly_df['income_from_ss'] + optimal_yearly_df['income_from_rmd'] + optimal_yearly_df['additional_ira_withdrawal'] + optimal_yearly_df['taxable_withdrawal'],
                 alpha=0.8, label='Taxable Withdrawals', color='mediumseagreen')
ax1.plot(years, optimal_yearly_df['income_need'], 'r--', linewidth=2, label='Income Need')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual Income ($)')
ax1.set_title('💵 INCOME SOURCES OVER TIME (Optimal Plan)')
ax1.legend(loc='upper left')
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e3:.0f}K'))
ax1.grid(True, alpha=0.3)

# Plot 2: Income Need vs Actual (Gap Analysis)
ax2 = axes[0, 1]
ax2.bar(years, optimal_yearly_df['total_income'], alpha=0.7, color='mediumseagreen', label='Total Income')
ax2.plot(years, optimal_yearly_df['income_need'], 'r-', linewidth=2, label='Income Need')
ax2.set_xlabel('Year')
ax2.set_ylabel('Amount ($)')
ax2.set_title('📊 Income Need vs Actual Income')
ax2.legend()
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e3:.0f}K'))
ax2.grid(True, alpha=0.3)

# Plot 3: Conversions in Context of Total Withdrawals
ax3 = axes[1, 0]
conversion_years_data = optimal_yearly_df[optimal_yearly_df['conversion'] > 0]
if len(conversion_years_data) > 0:
    conv_years = conversion_years_data['calendar_year']
    width = 0.35
    ax3.bar([y - width/2 for y in conv_years], conversion_years_data['conversion'], width, 
            label='Roth Conversion', color='mediumseagreen', alpha=0.8)
    ax3.bar([y + width/2 for y in conv_years], conversion_years_data['conv_tax'], width,
            label='Conversion Tax', color='indianred', alpha=0.8)
    ax3.set_xlabel('Year')
    ax3.set_ylabel('Amount ($)')
    ax3.set_title('🔄 Conversions and Tax Cost')
    ax3.legend()
    ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e3:.0f}K'))
else:
    ax3.text(0.5, 0.5, 'No conversions recommended', ha='center', va='center', transform=ax3.transAxes)
    ax3.set_title('🔄 Conversions and Tax Cost')

# Plot 4: Account Balance Trajectory
ax4 = axes[1, 1]
ax4.plot(years, optimal_yearly_df['taxable'], label='Taxable', color='gold', linewidth=2)
ax4.plot(years, optimal_yearly_df['s1_pretax'] + optimal_yearly_df['s2_pretax'], label='IRA (Pre-Tax)', color='coral', linewidth=2)
ax4.plot(years, optimal_yearly_df['s1_roth'] + optimal_yearly_df['s2_roth'], label='Roth', color='mediumseagreen', linewidth=2)
ax4.plot(years, optimal_yearly_df['total_balance'], label='Total', color='black', linewidth=2, linestyle='--')
ax4.set_xlabel('Year')
ax4.set_ylabel('Balance ($)')
ax4.set_title('📈 Account Balances Over Time')
ax4.legend()
ax4.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('income_and_wealth_plan.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'income_and_wealth_plan.png'")

# %%
# =============================================================================
# VISUALIZATION: WEALTH ACROSS ALL THREE BUCKETS
# =============================================================================

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Recommended Annual Conversions
ax1 = axes[0, 0]
years = [2025 + i for i in range(5)]
width = 0.35
ax1.bar([y - width/2 for y in years], [c * s1_ratio for c in optimal_conversions], width, 
        label=household.spouse1.name, color='steelblue', alpha=0.8)
ax1.bar([y + width/2 for y in years], [c * s2_ratio for c in optimal_conversions], width,
        label=household.spouse2.name, color='coral', alpha=0.8)
ax1.set_xlabel('Year')
ax1.set_ylabel('Conversion Amount ($)')
ax1.set_title('🎯 RECOMMENDED: Annual Conversions by Spouse')
ax1.legend()
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
for i, (y, c) in enumerate(zip(years, optimal_conversions)):
    ax1.text(y, c + 5000, f'${c:,.0f}', ha='center', va='bottom', fontsize=9, fontweight='bold')

# Plot 2: Final Bucket Balances Comparison
ax2 = axes[0, 1]
buckets = ['Taxable\n(Post-Tax)', 'IRA\n(Pre-Tax)', 'Roth\n(Tax-Free)']
no_conv_vals = [no_conv_outcome['final_taxable'], no_conv_outcome['final_pretax'], no_conv_outcome['final_roth']]
optimal_vals = [optimal_outcome['final_taxable'], optimal_outcome['final_pretax'], optimal_outcome['final_roth']]

x = np.arange(len(buckets))
ax2.bar(x - width/2, no_conv_vals, width, label='No Conversion', color='gray', alpha=0.7)
ax2.bar(x + width/2, optimal_vals, width, label='Optimal Plan', color='mediumseagreen', alpha=0.8)
ax2.set_ylabel('Final Balance ($)')
ax2.set_title('📊 Final Balances by Bucket (25 Years)')
ax2.set_xticks(x)
ax2.set_xticklabels(buckets)
ax2.legend()
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))

# Plot 3: After-Tax Wealth Comparison (the key chart!)
ax3 = axes[1, 0]
buckets_short = ['Taxable', 'IRA\n(after tax)', 'Roth']
no_conv_at = [no_conv_outcome['taxable_after_tax_value'], no_conv_outcome['pretax_after_tax_value'], no_conv_outcome['roth_after_tax_value']]
optimal_at = [optimal_outcome['taxable_after_tax_value'], optimal_outcome['pretax_after_tax_value'], optimal_outcome['roth_after_tax_value']]

ax3.bar(x - width/2, no_conv_at, width, label='No Conversion', color='indianred', alpha=0.7)
ax3.bar(x + width/2, optimal_at, width, label='Optimal Plan', color='mediumseagreen', alpha=0.8)
ax3.set_ylabel('After-Tax Value ($)')
ax3.set_title('💰 AFTER-TAX WEALTH by Bucket')
ax3.set_xticks(x)
ax3.set_xticklabels(buckets_short)
ax3.legend()
ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))

# Add total after-tax wealth annotation
total_no_conv = sum(no_conv_at)
total_optimal = sum(optimal_at)
ax3.annotate(f'Total: ${total_optimal/1e6:.2f}M\n(+${(total_optimal-total_no_conv)/1e3:.0f}K)', 
             xy=(2.3, total_optimal/3), fontsize=10, fontweight='bold', color='darkgreen')

# Plot 4: Account Balance Progression Over Time
ax4 = axes[1, 1]
all_years = optimal_yearly_df['calendar_year']

# Stack the three buckets
ax4.fill_between(all_years, 0, optimal_yearly_df['taxable'], 
                 alpha=0.7, label='Taxable', color='gold')
ax4.fill_between(all_years, optimal_yearly_df['taxable'], 
                 optimal_yearly_df['taxable'] + optimal_yearly_df['s1_pretax'] + optimal_yearly_df['s2_pretax'],
                 alpha=0.7, label='IRA (Pre-Tax)', color='coral')
ax4.fill_between(all_years, 
                 optimal_yearly_df['taxable'] + optimal_yearly_df['s1_pretax'] + optimal_yearly_df['s2_pretax'],
                 optimal_yearly_df['taxable'] + optimal_yearly_df['s1_pretax'] + optimal_yearly_df['s2_pretax'] + optimal_yearly_df['s1_roth'] + optimal_yearly_df['s2_roth'],
                 alpha=0.7, label='Roth', color='mediumseagreen')

ax4.set_xlabel('Year')
ax4.set_ylabel('Total Balance ($)')
ax4.set_title('📈 Total Wealth by Bucket Over Time')
ax4.legend(loc='upper left')
ax4.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('optimal_wealth_plan.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'optimal_wealth_plan.png'")

# %%
# =============================================================================
# EXECUTIVE SUMMARY: YOUR ACTION PLAN
# =============================================================================

wealth_gain = optimal_outcome['total_after_tax_wealth'] - no_conv_outcome['total_after_tax_wealth']
rmd_reduction_total = rmd_only['RMD_Reduction'].sum() if len(rmd_only) > 0 else 0
total_conv = sum(optimal_conversions)
total_income_25yr = optimal_yearly_df['total_income'].sum()

print("=" * 100)
print("📋 EXECUTIVE SUMMARY: YOUR ROTH CONVERSION ACTION PLAN")
print("=" * 100)

print(f"""
┌─────────────────────────────────────────────────────────────────────────────────────────────────────┐
│  💵 GUARANTEED INCOME: ${MONTHLY_INCOME_NEED:,}/month = ${ANNUAL_INCOME_NEED:,}/year (inflation-adjusted)                         │
└─────────────────────────────────────────────────────────────────────────────────────────────────────┘

┌─────────────────────────────────────────────────────────────────────────────────────────────────┐
│  YEAR   │  CONVERT FROM {household.spouse1.name.upper():<8}  │  CONVERT FROM {household.spouse2.name.upper():<8}  │  TOTAL        │  TAX COST     │
├─────────────────────────────────────────────────────────────────────────────────────────────────┤""")

for i in range(5):
    year = 2025 + i
    row = optimal_yearly_df.iloc[i]
    print(f"│  {year}   │     ${row['s1_conv']:>12,.0f}      │     ${row['s2_conv']:>12,.0f}      │  ${row['conversion']:>10,.0f}  │  ${row['conv_tax']:>10,.0f}  │")

print(f"""├─────────────────────────────────────────────────────────────────────────────────────────────────┤
│  TOTAL  │     ${total_conv*s1_ratio:>12,.0f}      │     ${total_conv*s2_ratio:>12,.0f}      │  ${total_conv:>10,.0f}  │  ${optimal_outcome['total_conversion_taxes']:>10,.0f}  │
└─────────────────────────────────────────────────────────────────────────────────────────────────┘

📊 ASSET ALLOCATION BY BUCKET:
   • Taxable (Post-Tax):  {TAXABLE_ALLOCATION[0]*100:.0f}% stocks / {TAXABLE_ALLOCATION[1]*100:.0f}% bonds → {TAXABLE_RETURN*100:.1f}% expected return
   • Traditional IRA:     {IRA_ALLOCATION[0]*100:.0f}% stocks / {IRA_ALLOCATION[1]*100:.0f}% bonds → {IRA_RETURN*100:.1f}% expected return
   • Roth IRA:            {ROTH_ALLOCATION[0]*100:.0f}% stocks / {ROTH_ALLOCATION[1]*100:.0f}% bonds → {ROTH_RETURN*100:.1f}% expected return

💵 INCOME GUARANTEE (25-year projection):
   ✅ Total income delivered:             ${total_income_25yr:>12,.0f}
   ✅ Income shortfall:                   ${optimal_outcome['total_income_shortfall']:>12,.0f}
   ✅ Income sources: SS + RMDs + IRA withdrawals + Taxable (in priority order)

💰 KEY WEALTH BENEFITS OF THIS PLAN:
   ✅ Total after-tax wealth GAIN:        ${wealth_gain:>12,.0f}
   ✅ Total RMDs reduced by:              ${rmd_reduction_total:>12,.0f}
   ✅ Final Roth balance (tax-free):      ${optimal_outcome['final_roth']:>12,.0f}
   ✅ Final taxable account:              ${optimal_outcome['final_taxable']:>12,.0f}
   ✅ Final IRA (pre-tax):                ${optimal_outcome['final_pretax']:>12,.0f}

📈 WHY ROTH GETS HIGHER STOCK ALLOCATION:
   • Roth grows tax-free forever - maximize growth with 80/20
   • IRA will be taxed at ordinary rates - more conservative 60/40
   • Taxable has annual tax drag on dividends - balanced 70/30

📝 IMPLEMENTATION NOTES:
   • Income is prioritized FIRST - conversions only when funds remain
   • Convert from Traditional IRA and SEP-IRA (both are pre-tax)
   • Pay conversion taxes from your taxable account (not the IRA)
   • Consider converting in December when you know full year's income
   • File Form 8606 for each spouse's conversion
""")

# %%
# Visualization for household
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Conversion amounts by spouse
ax1 = axes[0, 0]
width = 0.35
x = np.arange(len(household_plan))
ax1.bar(x - width/2, household_plan[f'{household.spouse1.name}_Conversion'], width, 
        label=household.spouse1.name, color='steelblue')
ax1.bar(x + width/2, household_plan[f'{household.spouse2.name}_Conversion'], width,
        label=household.spouse2.name, color='coral')
ax1.set_xlabel('Year')
ax1.set_ylabel('Conversion Amount ($)')
ax1.set_title('Annual Conversions by Spouse')
ax1.set_xticks(x)
ax1.set_xticklabels(household_plan['Calendar_Year'])
ax1.legend()
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# Plot 2: Account balance progression
ax2 = axes[0, 1]
years = household_plan['Calendar_Year']
ax2.stackplot(years, 
              household_plan[f'{household.spouse1.name}_PreTax'],
              household_plan[f'{household.spouse2.name}_PreTax'],
              household_plan[f'{household.spouse1.name}_Roth'],
              household_plan[f'{household.spouse2.name}_Roth'],
              labels=[f'{household.spouse1.name} Pre-Tax', f'{household.spouse2.name} Pre-Tax',
                     f'{household.spouse1.name} Roth', f'{household.spouse2.name} Roth'],
              colors=['indianred', 'lightsalmon', 'mediumseagreen', 'lightgreen'],
              alpha=0.8)
ax2.set_xlabel('Year')
ax2.set_ylabel('Balance ($)')
ax2.set_title('Account Balance Progression')
ax2.legend(loc='upper left', fontsize=8)
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# Plot 3: Taxes paid
ax3 = axes[1, 0]
ax3.bar(household_plan['Calendar_Year'], household_plan['Federal_Tax'], 
        label='Federal', color='indianred')
ax3.bar(household_plan['Calendar_Year'], household_plan['State_Tax'],
        bottom=household_plan['Federal_Tax'], label='State', color='goldenrod')
ax3.set_xlabel('Year')
ax3.set_ylabel('Tax ($)')
ax3.set_title('Taxes Paid on Conversions')
ax3.legend()
ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# Plot 4: Pre-Tax vs Roth over time
ax4 = axes[1, 1]
ax4.plot(years, household_plan['Total_PreTax'], 'o-', label='Total Pre-Tax', 
         color='indianred', linewidth=2, markersize=8)
ax4.plot(years, household_plan['Total_Roth'], 's-', label='Total Roth',
         color='mediumseagreen', linewidth=2, markersize=8)
ax4.set_xlabel('Year')
ax4.set_ylabel('Balance ($)')
ax4.set_title('Pre-Tax vs Roth Balance Over Time')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

plt.tight_layout()
plt.savefig('household_roth_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'household_roth_analysis.png'")

# %% [markdown]
# ## Tax Calculation Functions

# %%
def calculate_federal_tax(taxable_income: float, brackets: List[Tuple[float, float]]) -> float:
    """Calculate federal income tax based on taxable income and brackets."""
    if taxable_income <= 0:
        return 0
    
    tax = 0
    prev_limit = 0
    
    for limit, rate in brackets:
        if taxable_income <= prev_limit:
            break
        
        taxable_in_bracket = min(taxable_income, limit) - prev_limit
        if taxable_in_bracket > 0:
            tax += taxable_in_bracket * rate
        
        prev_limit = limit
    
    return tax


def get_marginal_rate(taxable_income: float, brackets: List[Tuple[float, float]]) -> float:
    """Get the marginal tax rate for a given taxable income."""
    prev_limit = 0
    for limit, rate in brackets:
        if taxable_income <= limit:
            return rate
        prev_limit = limit
    return brackets[-1][1]


def calculate_total_tax(
    profile: TaxpayerProfile,
    conversion_amount: float,
    year: int = 0
) -> Tuple[float, float, float]:
    """Calculate total tax (federal + state) for a given conversion amount.
    
    Returns: (federal_tax, state_tax, total_tax)
    """
    # Get inflation-adjusted values
    standard_deduction = profile.get_standard_deduction(year)
    brackets = profile.get_tax_brackets(year)
    
    # Calculate adjusted other income for inflation
    other_income = profile.other_taxable_income * ((1 + profile.inflation_rate) ** year)
    
    # Total gross income
    gross_income = other_income + conversion_amount
    
    # Taxable income after standard deduction
    taxable_income = max(0, gross_income - standard_deduction)
    
    # Calculate federal tax
    federal_tax = calculate_federal_tax(taxable_income, brackets)
    
    # Calculate state tax (simplified - flat rate on taxable income)
    state_tax = taxable_income * profile.state_tax_rate
    
    total_tax = federal_tax + state_tax
    
    return federal_tax, state_tax, total_tax


# Test the tax calculation
test_conversion = 50000
fed_tax, state_tax, total_tax = calculate_total_tax(example_profile, test_conversion, 0)
print(f"Test conversion of ${test_conversion:,.0f}:")
print(f"  Federal Tax: ${fed_tax:,.2f}")
print(f"  State Tax: ${state_tax:,.2f}")
print(f"  Total Tax: ${total_tax:,.2f}")
print(f"  Effective Rate: {total_tax/test_conversion*100:.1f}%")

# %% [markdown]
# ## Optimal Conversion Amount Calculator
# Find the optimal conversion amount to fill up to a target tax bracket.

# %%
def find_bracket_top(
    profile: TaxpayerProfile,
    target_rate: float,
    year: int = 0
) -> float:
    """Find the income level at the top of the target bracket."""
    brackets = profile.get_tax_brackets(year)
    
    for limit, rate in brackets:
        if rate == target_rate:
            return limit
    
    # If target rate not found, return the limit just before the next higher rate
    prev_limit = 0
    for limit, rate in brackets:
        if rate > target_rate:
            return prev_limit
        prev_limit = limit
    
    return brackets[-2][0]  # Return second-to-last bracket limit


def calculate_optimal_conversion(
    profile: TaxpayerProfile,
    year: int = 0
) -> Dict:
    """Calculate the optimal Roth conversion amount to fill target bracket.
    
    Returns a dictionary with conversion details.
    """
    standard_deduction = profile.get_standard_deduction(year)
    brackets = profile.get_tax_brackets(year)
    
    # Inflation-adjusted other income
    other_income = profile.other_taxable_income * ((1 + profile.inflation_rate) ** year)
    
    # Current taxable income without conversion
    current_taxable = max(0, other_income - standard_deduction)
    current_marginal_rate = get_marginal_rate(current_taxable, brackets)
    
    # Find top of target bracket
    bracket_top = find_bracket_top(profile, profile.target_bracket, year)
    
    # Calculate optimal conversion to fill target bracket
    # Taxable income at bracket top
    target_taxable = bracket_top
    
    # Gross income needed to achieve target taxable income
    target_gross = target_taxable + standard_deduction
    
    # Optimal conversion amount
    optimal_conversion = max(0, target_gross - other_income)
    
    # Calculate taxes at optimal conversion
    fed_tax, state_tax, total_tax = calculate_total_tax(profile, optimal_conversion, year)
    
    return {
        'year': year,
        'calendar_year': 2024 + year,
        'other_income': other_income,
        'standard_deduction': standard_deduction,
        'current_taxable_income': current_taxable,
        'current_marginal_rate': current_marginal_rate,
        'target_bracket': profile.target_bracket,
        'bracket_top': bracket_top,
        'optimal_conversion': optimal_conversion,
        'federal_tax': fed_tax,
        'state_tax': state_tax,
        'total_tax': total_tax,
        'effective_tax_rate': total_tax / optimal_conversion if optimal_conversion > 0 else 0
    }


# Calculate optimal conversion for year 0
result = calculate_optimal_conversion(example_profile, 0)
print("Optimal Conversion Analysis for Year 1 (2024):")
print(f"  Other Income: ${result['other_income']:,.0f}")
print(f"  Standard Deduction: ${result['standard_deduction']:,.0f}")
print(f"  Current Marginal Rate: {result['current_marginal_rate']*100:.0f}%")
print(f"  Target Bracket: {result['target_bracket']*100:.0f}%")
print(f"  Optimal Conversion: ${result['optimal_conversion']:,.0f}")
print(f"  Total Tax on Conversion: ${result['total_tax']:,.0f}")
print(f"  Effective Rate: {result['effective_tax_rate']*100:.1f}%")

# %% [markdown]
# ## 5-Year Roth Conversion Optimization

# %%
def optimize_5_year_conversions(
    profile: TaxpayerProfile,
    years: int = 5
) -> pd.DataFrame:
    """Calculate optimal Roth conversions over multiple years.
    
    This tracks IRA balances and calculates year-by-year optimal conversions.
    """
    results = []
    
    # Track balances
    trad_balance = profile.traditional_ira_balance
    roth_balance = profile.roth_ira_balance
    total_taxes_paid = 0
    total_converted = 0
    
    for year in range(years):
        # Calculate optimal conversion for this year
        conversion_info = calculate_optimal_conversion(profile, year)
        
        # Cap conversion at available traditional IRA balance
        actual_conversion = min(conversion_info['optimal_conversion'], trad_balance)
        
        # Recalculate tax for actual conversion amount
        fed_tax, state_tax, total_tax = calculate_total_tax(profile, actual_conversion, year)
        
        # Update balances
        # Apply growth first (beginning of year)
        trad_balance *= (1 + profile.expected_return)
        roth_balance *= (1 + profile.expected_return)
        
        # Then do conversion (end of year)
        trad_balance -= actual_conversion
        roth_balance += actual_conversion
        
        total_taxes_paid += total_tax
        total_converted += actual_conversion
        
        results.append({
            'Year': year + 1,
            'Calendar_Year': 2024 + year,
            'Age': profile.age + year,
            'Other_Income': conversion_info['other_income'],
            'Conversion_Amount': actual_conversion,
            'Federal_Tax': fed_tax,
            'State_Tax': state_tax,
            'Total_Tax': total_tax,
            'Effective_Rate': (total_tax / actual_conversion * 100) if actual_conversion > 0 else 0,
            'Trad_IRA_Balance': trad_balance,
            'Roth_IRA_Balance': roth_balance,
            'Cumulative_Converted': total_converted,
            'Cumulative_Taxes': total_taxes_paid
        })
    
    df = pd.DataFrame(results)
    return df


# Run the 5-year optimization
conversion_plan = optimize_5_year_conversions(example_profile, years=5)
print("5-Year Roth Conversion Plan")
print("=" * 80)
conversion_plan

# %%
# Summary statistics
print("\n" + "=" * 60)
print("5-YEAR ROTH CONVERSION SUMMARY")
print("=" * 60)
print(f"\nInitial Traditional IRA Balance: ${example_profile.traditional_ira_balance:,.0f}")
print(f"Initial Roth IRA Balance: ${example_profile.roth_ira_balance:,.0f}")
print(f"\nTotal Amount Converted: ${conversion_plan['Conversion_Amount'].sum():,.0f}")
print(f"Total Taxes Paid: ${conversion_plan['Total_Tax'].sum():,.0f}")
print(f"Average Effective Tax Rate: {conversion_plan['Effective_Rate'].mean():.1f}%")
print(f"\nFinal Traditional IRA Balance: ${conversion_plan['Trad_IRA_Balance'].iloc[-1]:,.0f}")
print(f"Final Roth IRA Balance: ${conversion_plan['Roth_IRA_Balance'].iloc[-1]:,.0f}")
print(f"Final Total IRA Balance: ${conversion_plan['Trad_IRA_Balance'].iloc[-1] + conversion_plan['Roth_IRA_Balance'].iloc[-1]:,.0f}")

# %% [markdown]
# ## Visualization

# %%
# Create visualizations
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Conversion amounts by year
ax1 = axes[0, 0]
ax1.bar(conversion_plan['Calendar_Year'], conversion_plan['Conversion_Amount'], 
        color='steelblue', edgecolor='navy')
ax1.set_xlabel('Year')
ax1.set_ylabel('Conversion Amount ($)')
ax1.set_title('Annual Roth Conversion Amounts')
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
for i, v in enumerate(conversion_plan['Conversion_Amount']):
    ax1.text(conversion_plan['Calendar_Year'].iloc[i], v + 2000, f'${v:,.0f}', 
             ha='center', va='bottom', fontsize=9)

# Plot 2: IRA Balance Progression
ax2 = axes[0, 1]
years = conversion_plan['Calendar_Year']
ax2.fill_between(years, 0, conversion_plan['Trad_IRA_Balance'], 
                 alpha=0.7, label='Traditional IRA', color='coral')
ax2.fill_between(years, conversion_plan['Trad_IRA_Balance'], 
                 conversion_plan['Trad_IRA_Balance'] + conversion_plan['Roth_IRA_Balance'],
                 alpha=0.7, label='Roth IRA', color='mediumseagreen')
ax2.set_xlabel('Year')
ax2.set_ylabel('Balance ($)')
ax2.set_title('IRA Balance Progression')
ax2.legend(loc='upper right')
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# Plot 3: Taxes paid by year
ax3 = axes[1, 0]
width = 0.35
x = np.arange(len(years))
ax3.bar(x - width/2, conversion_plan['Federal_Tax'], width, label='Federal Tax', color='indianred')
ax3.bar(x + width/2, conversion_plan['State_Tax'], width, label='State Tax', color='goldenrod')
ax3.set_xlabel('Year')
ax3.set_ylabel('Tax Amount ($)')
ax3.set_title('Taxes Paid on Conversions')
ax3.set_xticks(x)
ax3.set_xticklabels(years)
ax3.legend()
ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# Plot 4: Cumulative conversions and taxes
ax4 = axes[1, 1]
ax4.plot(years, conversion_plan['Cumulative_Converted'], 'o-', 
         label='Cumulative Converted', color='steelblue', linewidth=2, markersize=8)
ax4.plot(years, conversion_plan['Cumulative_Taxes'], 's-', 
         label='Cumulative Taxes', color='indianred', linewidth=2, markersize=8)
ax4.set_xlabel('Year')
ax4.set_ylabel('Amount ($)')
ax4.set_title('Cumulative Conversions vs Taxes Paid')
ax4.legend()
ax4.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('roth_conversion_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'roth_conversion_analysis.png'")

# %% [markdown]
# ## Advanced Optimization: Minimize Lifetime Taxes
#
# This section uses optimization to find the best conversion amounts that minimize total lifetime taxes, considering future RMDs and growth.

# %%
def calculate_rmd_factor(age: int) -> float:
    """Get the RMD distribution period based on age (Uniform Lifetime Table)."""
    # Simplified RMD factors - starts at age 73
    rmd_table = {
        73: 26.5, 74: 25.5, 75: 24.6, 76: 23.7, 77: 22.9,
        78: 22.0, 79: 21.1, 80: 20.2, 81: 19.4, 82: 18.5,
        83: 17.7, 84: 16.8, 85: 16.0, 86: 15.2, 87: 14.4,
        88: 13.7, 89: 12.9, 90: 12.2, 91: 11.5, 92: 10.8,
        93: 10.1, 94: 9.5, 95: 8.9, 96: 8.4, 97: 7.8,
        98: 7.3, 99: 6.8, 100: 6.4
    }
    if age < 73:
        return 0  # No RMD required
    if age > 100:
        return 6.4
    return rmd_table.get(age, 6.4)


def project_lifetime_taxes(
    profile: TaxpayerProfile,
    conversion_amounts: List[float],
    projection_years: int = 30
) -> Dict:
    """Project lifetime taxes with given conversion strategy.
    
    Args:
        profile: Taxpayer profile
        conversion_amounts: List of conversion amounts for each year
        projection_years: Years to project (default 30)
    
    Returns:
        Dictionary with projection results
    """
    trad_balance = profile.traditional_ira_balance
    roth_balance = profile.roth_ira_balance
    
    total_conversion_taxes = 0
    total_rmd_taxes = 0
    yearly_data = []
    
    conversion_years = len(conversion_amounts)
    
    for year in range(projection_years):
        age = profile.age + year
        
        # Apply growth
        trad_balance *= (1 + profile.expected_return)
        roth_balance *= (1 + profile.expected_return)
        
        # Determine conversion (only during conversion period)
        if year < conversion_years:
            conversion = min(conversion_amounts[year], max(0, trad_balance))
        else:
            conversion = 0
        
        # Calculate RMD (if applicable)
        rmd_factor = calculate_rmd_factor(age)
        if rmd_factor > 0:
            rmd = trad_balance / rmd_factor
        else:
            rmd = 0
        
        # Total taxable distribution
        total_distribution = conversion + rmd
        
        # Calculate taxes
        _, _, tax = calculate_total_tax(profile, total_distribution, year)
        
        # Allocate taxes between conversion and RMD
        if total_distribution > 0:
            conversion_tax = tax * (conversion / total_distribution)
            rmd_tax = tax * (rmd / total_distribution)
        else:
            conversion_tax = 0
            rmd_tax = 0
        
        total_conversion_taxes += conversion_tax
        total_rmd_taxes += rmd_tax
        
        # Update balances
        trad_balance -= (conversion + rmd)
        roth_balance += conversion  # RMD is withdrawn, not converted
        
        yearly_data.append({
            'year': year,
            'age': age,
            'trad_balance': trad_balance,
            'roth_balance': roth_balance,
            'conversion': conversion,
            'rmd': rmd,
            'tax': tax
        })
    
    return {
        'total_conversion_taxes': total_conversion_taxes,
        'total_rmd_taxes': total_rmd_taxes,
        'total_lifetime_taxes': total_conversion_taxes + total_rmd_taxes,
        'final_trad_balance': trad_balance,
        'final_roth_balance': roth_balance,
        'yearly_data': yearly_data
    }


# Test with current strategy
current_conversions = conversion_plan['Conversion_Amount'].tolist()
projection = project_lifetime_taxes(example_profile, current_conversions, 30)

print("30-Year Projection with Current Strategy:")
print(f"  Total Conversion Taxes: ${projection['total_conversion_taxes']:,.0f}")
print(f"  Total RMD Taxes: ${projection['total_rmd_taxes']:,.0f}")
print(f"  Total Lifetime Taxes: ${projection['total_lifetime_taxes']:,.0f}")

# %%
def optimize_conversions_scipy(
    profile: TaxpayerProfile,
    years: int = 5,
    projection_years: int = 30
) -> Tuple[List[float], Dict]:
    """Use scipy optimization to find optimal conversion amounts."""
    
    def objective(conversions):
        """Objective function to minimize total lifetime taxes."""
        result = project_lifetime_taxes(profile, list(conversions), projection_years)
        return result['total_lifetime_taxes']
    
    # Initial guess: equal conversions over the period
    initial_guess = [profile.traditional_ira_balance / years] * years
    
    # Bounds: 0 to full balance for each year
    bounds = [(0, profile.traditional_ira_balance) for _ in range(years)]
    
    # Use differential evolution for global optimization
    result = differential_evolution(
        objective,
        bounds,
        seed=42,
        maxiter=200,
        tol=100,
        workers=-1,
        updating='deferred'
    )
    
    optimal_conversions = list(result.x)
    optimal_projection = project_lifetime_taxes(profile, optimal_conversions, projection_years)
    
    return optimal_conversions, optimal_projection


print("Running optimization (this may take a moment)...")
optimal_conversions, optimal_result = optimize_conversions_scipy(example_profile, years=5)

print("\nOptimized 5-Year Conversion Strategy:")
print("=" * 50)
for i, conv in enumerate(optimal_conversions):
    print(f"  Year {i+1} ({2024+i}): ${conv:,.0f}")

print(f"\nTotal Converted: ${sum(optimal_conversions):,.0f}")
print(f"Lifetime Taxes (Optimized): ${optimal_result['total_lifetime_taxes']:,.0f}")
print(f"Lifetime Taxes (Bracket-Fill): ${projection['total_lifetime_taxes']:,.0f}")
print(f"Tax Savings: ${projection['total_lifetime_taxes'] - optimal_result['total_lifetime_taxes']:,.0f}")

# %% [markdown]
# ## Comparison: Different Strategies

# %%
def compare_strategies(profile: TaxpayerProfile) -> pd.DataFrame:
    """Compare different Roth conversion strategies."""
    strategies = {}
    
    # Strategy 1: No conversions
    no_conversion = project_lifetime_taxes(profile, [0, 0, 0, 0, 0], 30)
    strategies['No Conversion'] = no_conversion
    
    # Strategy 2: Fill 12% bracket
    profile_12 = TaxpayerProfile(**{**profile.__dict__, 'target_bracket': 0.12})
    plan_12 = optimize_5_year_conversions(profile_12, 5)
    result_12 = project_lifetime_taxes(profile, plan_12['Conversion_Amount'].tolist(), 30)
    strategies['Fill 12% Bracket'] = result_12
    
    # Strategy 3: Fill 22% bracket (current)
    result_22 = project_lifetime_taxes(profile, current_conversions, 30)
    strategies['Fill 22% Bracket'] = result_22
    
    # Strategy 4: Fill 24% bracket
    profile_24 = TaxpayerProfile(**{**profile.__dict__, 'target_bracket': 0.24})
    plan_24 = optimize_5_year_conversions(profile_24, 5)
    result_24 = project_lifetime_taxes(profile, plan_24['Conversion_Amount'].tolist(), 30)
    strategies['Fill 24% Bracket'] = result_24
    
    # Strategy 5: Optimized (from scipy)
    strategies['Optimized'] = optimal_result
    
    # Create comparison dataframe
    comparison_data = []
    for name, result in strategies.items():
        comparison_data.append({
            'Strategy': name,
            'Conversion_Taxes': result['total_conversion_taxes'],
            'RMD_Taxes': result['total_rmd_taxes'],
            'Total_Lifetime_Taxes': result['total_lifetime_taxes'],
            'Final_Roth_Balance': result['final_roth_balance'],
            'Final_Trad_Balance': result['final_trad_balance']
        })
    
    df = pd.DataFrame(comparison_data)
    df['Tax_Savings_vs_NoConversion'] = df['Total_Lifetime_Taxes'].iloc[0] - df['Total_Lifetime_Taxes']
    
    return df


comparison_df = compare_strategies(example_profile)
print("Strategy Comparison (30-Year Projection)")
print("=" * 80)
comparison_df

# %%
# Visualize strategy comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Total lifetime taxes by strategy
ax1 = axes[0]
colors = ['lightcoral', 'lightsalmon', 'khaki', 'lightgreen', 'mediumseagreen']
bars = ax1.barh(comparison_df['Strategy'], comparison_df['Total_Lifetime_Taxes'], color=colors)
ax1.set_xlabel('Total Lifetime Taxes ($)')
ax1.set_title('30-Year Lifetime Tax Comparison')
ax1.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# Add value labels
for bar, val in zip(bars, comparison_df['Total_Lifetime_Taxes']):
    ax1.text(val + 2000, bar.get_y() + bar.get_height()/2, 
             f'${val:,.0f}', va='center', fontsize=9)

# Plot 2: Final account balances
ax2 = axes[1]
x = np.arange(len(comparison_df))
width = 0.35
ax2.barh(x - width/2, comparison_df['Final_Trad_Balance'], width, 
         label='Traditional IRA', color='coral')
ax2.barh(x + width/2, comparison_df['Final_Roth_Balance'], width, 
         label='Roth IRA', color='mediumseagreen')
ax2.set_yticks(x)
ax2.set_yticklabels(comparison_df['Strategy'])
ax2.set_xlabel('Final Balance ($)')
ax2.set_title('Final IRA Balances After 30 Years')
ax2.legend()
ax2.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

plt.tight_layout()
plt.savefig('strategy_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nChart saved as 'strategy_comparison.png'")

# %% [markdown]
# ## Interactive Configuration
#
# Modify the profile below to analyze your own situation:

# %%
# =============================================================================
# MODIFY YOUR PROFILE HERE
# =============================================================================

my_profile = TaxpayerProfile(
    name="Your Name",
    age=60,                           # Your current age
    filing_status='mfj',              # 'mfj' (married filing jointly) or 'single'
    traditional_ira_balance=400000,   # Your Traditional IRA balance
    roth_ira_balance=50000,           # Your Roth IRA balance
    other_taxable_income=50000,       # Other income (Social Security, pension, wages)
    state_tax_rate=0.05,              # Your state tax rate (0 if no state tax)
    expected_return=0.06,             # Expected investment return (6% = 0.06)
    inflation_rate=0.025,             # Expected inflation (2.5% = 0.025)
    target_bracket=0.22,              # Target tax bracket to fill
    spouse_age=58                     # Spouse age (if married)
)

# Run analysis
print(f"Analyzing profile for: {my_profile.name}")
print("=" * 60)

my_plan = optimize_5_year_conversions(my_profile, years=5)
print("\n5-Year Conversion Plan:")
display(my_plan[['Calendar_Year', 'Age', 'Conversion_Amount', 'Total_Tax', 'Effective_Rate', 
                 'Trad_IRA_Balance', 'Roth_IRA_Balance']])

print(f"\nTotal to Convert: ${my_plan['Conversion_Amount'].sum():,.0f}")
print(f"Total Taxes: ${my_plan['Total_Tax'].sum():,.0f}")
print(f"Average Effective Rate: {my_plan['Effective_Rate'].mean():.1f}%")

# %% [markdown]
# ## Key Considerations & Disclaimers
#
# ### Important Notes:
# 1. **This is for educational purposes only** - Consult a qualified tax professional before making any conversion decisions
# 2. **Tax laws change** - Brackets and rules may be different in future years
# 3. **IRMAA implications** - Large conversions may increase Medicare premiums
# 4. **State taxes vary** - Some states don't tax retirement income
# 5. **Pro-rata rule** - If you have non-deductible Traditional IRA contributions, calculations will differ
# 6. **Capital gains** - Consider impact on investment income taxation
# 7. **Estate planning** - Roth conversions can be beneficial for heirs
#
# ### Factors Not Included in This Model:
# - Medicare IRMAA surcharges
# - Social Security taxation thresholds
# - Net Investment Income Tax (NIIT)
# - State-specific retirement income exclusions
# - ACA subsidy impacts
# - Estate tax considerations
